# %% [markdown]
# This notebook is the scratch paper I used while writing [`evaluate.py`](./evaluate.py). I used this whenever I needed an interactive console to try ideas and view results.

# %% [markdown]
# ## Load and run `evaluate` module

# %%
from importlib import reload # recompile module and re-execute module-level code
import evaluate as ev; reload(ev)
# Out:
# <module 'evaluate' from 'D:\\This PC\\Documents\\Github\\nlp-sandbox\\enron\\evaluate.py'>

# %%
# %run -i evaluate.py
# Out:
# Importing the model from model.pkl
# Loading test data
# notes.cleaned.tsv
# Featurizing test data
# Evaluating
#
# Accuracy: 0.32044560943643513
#
# Confusion matrix:
# Layout
# [[tn   fp]
#  [fn   tp]]
#
# [[ 393 1036]
#  [   1   96]]
#
# Classification report:
#              precision    recall  f1-score   support
#
#         neg       1.00      0.28      0.43      1429
#         pos       0.08      0.99      0.16        97
#
# avg / total       0.94      0.32      0.41      1526
#
#
# Accuracy (on candidates with 1+ feature): 0.7192691029900332
#
# Confusion matrix:
# [[393 168]
#  [  1  40]]
#
# Classification report:
#              precision    recall  f1-score   support
#
#         neg       1.00      0.70      0.82       561
#         pos       0.19      0.98      0.32        41
#
# avg / total       0.94      0.72      0.79       602

# %% [markdown]
# **Improvement #1**: accuracy filtering above shows the model should learn to be more uncertain about candidates it has zero features on.
#    - This could mean not requiring a VERB in order for a candidate to have features. (Although might be reasonable to scope this problem to tasks of this form first, nail it, then expand the definition)
#    - This could mean not including training data with 0 features, with the idea that this will force the model to be more uncertain when it comes across 0-feature candidates in test. But is this a bad bias to introduce?

# %% [markdown]
# **Improvement #2**: re-train model using spacy v2
#
# I decided to upgrade spacy in the middle of building this notebook (to use the `displacy` visualizer package later on). Went from `1.9.0` to `2.0.7`. Didn't expect it to affect much until I re-train my model. Wrong.
#
# **Measure**|**v1.9.0**|**v2.0.7 (eval-only)**
# -----|-----|-----
# Accuracy|0.286|0.312
# Accuracy on 1+ features|0.633|0.698
# Confusion Matrix|[[ 356 1086] [ 4 80]]|[[ 393 1049] [ 1 83]]
# Confusion Matrix on 1+ features|[[356 216] [ 4 24]]|[[393 181] [ 1 27]]
#
# So I'm excited to see more performance boosts simply from upgrading Spacy!
#
# _On the negative side, featurization is slower._
#
# Other options after upgrade:
# - Add [new morphology info](https://spacy.io/api/annotation#pos-tagging) as features (VerbForm, Tense, Aspect)

# %% [markdown]
# **TODO**: address label inbalance

# %% [markdown]
# ## Using: get_sample_predictions

# %%
most_incorrect = ev.get_sample_predictions(preds_df, sample_type=ev.SamplePredictions.MOST_INCORRECT, n=20)
most_incorrect
# Out:
#                                          candidate_task  \
# 396   ENA Origination Support (Getting info from Tyc...
# 926   wanted only to buy and sell conventional reins...
# 1091  end, after court hearings on the issue, the Dr...
# 1023  the market observations (as opposed to histori...
# 1121  late Tuesday accused 29 Enron officers and dir...
# 777   John Elder, creator of a grass-roots investmen...
# 167                  Managing Director, Enterprise Risk
# 1282                                            use the
# 803   2. Decision support system: a model recommendi...
# 196                                Published: June 2000
# 1111  payments as necessary "in order to protect and...
# 1103  prove - then the judge can void the payments a...
# 805   3. Fully automated trading system, setting pri...
# 1118  to petition the bankruptcy court to cash in un...
# 1011  massive directional trading and representing h...
# 964                    contracts based on cold weather.
# 828          13 files sent for R (public version of S).
# 256            Key risks associated with each category:
# 1063  bonuses to about 500 employees, according to s...
# 752              Please note your account 00235424-0015
#
#                       prob_dist label  \
# 396   <ProbDist with 2 samples>   neg
# 926   <ProbDist with 2 samples>   neg
# 1091  <ProbDist with 2 samples>   neg
# 1023  <ProbDist with 2 samples>   neg
# 1121  <ProbDist with 2 samples>   neg
# 777   <ProbDist with 2 samples>   neg
# 167   <ProbDist with 2 samples>   neg
# 1282  <ProbDist with 2 samples>   neg
# 803   <ProbDist with 2 samples>   neg
# 196   <ProbDist with 2 samples>   neg
# 1111  <ProbDist with 2 samples>   neg
# 1103  <ProbDist with 2 samples>   neg
# 805   <ProbDist with 2 samples>   neg
# 1118  <ProbDist with 2 samples>   neg
# 1011  <ProbDist with 2 samples>   neg
# 964   <ProbDist with 2 samples>   neg
# 828   <ProbDist with 2 samples>   neg
# 256   <ProbDist with 2 samples>   neg
# 1063  <ProbDist with 2 samples>   neg
# 752   <ProbDist with 2 samples>   neg
#
#                                                features pred  pos_dist  \
# 396   {'VERB': 1, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...  pos  0.973595
# 926   {'VERB': 3, 'FOLLOWING_POS_ADV': 1, 'FOLLOWING...  pos  0.928333
# 1091  {'VERB': 1, 'FOLLOWING_POS_PUNCT': 1, 'FOLLOWI...  pos  0.907394
# 1023  {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.881702
# 1121  {'VERB': 1, 'FOLLOWING_POS_NUM': 1, 'FOLLOWING...  pos  0.880221
# 777   {'VERB': 1, 'PARENT_DEP_ROOT': 1, 'PARENT_POS_...  pos  0.879704
# 167   {'VERB': 1, 'FOLLOWING_POS_PROPN': 1, 'FOLLOWI...  pos  0.877372
# 1282  {'VERB': 1, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  pos  0.873541
# 803   {'VERB': 1, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...  pos  0.869085
# 196   {'VERB': 1, 'FOLLOWING_POS_PUNCT': 1, 'FOLLOWI...  pos  0.860724
# 1111  {'VERB': 2, 'FOLLOWING_POS_CCONJ': 1, 'FOLLOWI...  pos  0.854629
# 1103  {'VERB': 3, 'FOLLOWING_POS_PUNCT': 1, 'FOLLOWI...  pos  0.849897
# 805   {'VERB': 3, 'FOLLOWING_POS_NOUN': 3, 'FOLLOWIN...  pos  0.839242
# 1118  {'VERB': 2, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  pos  0.838322
# 1011  {'VERB': 2, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.833685
# 964   {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.829239
# 828   {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.829239
# 256   {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.829239
# 1063  {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.829239
# 752   {'VERB': 1, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.827766
#
#       neg_dist  max_dist
# 396   0.026405  0.973595
# 926   0.071667  0.928333
# 1091  0.092606  0.907394
# 1023  0.118298  0.881702
# 1121  0.119779  0.880221
# 777   0.120296  0.879704
# 167   0.122628  0.877372
# 1282  0.126459  0.873541
# 803   0.130915  0.869085
# 196   0.139276  0.860724
# 1111  0.145371  0.854629
# 1103  0.150103  0.849897
# 805   0.160758  0.839242
# 1118  0.161678  0.838322
# 1011  0.166315  0.833685
# 964   0.170761  0.829239
# 828   0.170761  0.829239
# 256   0.170761  0.829239
# 1063  0.170761  0.829239
# 752   0.172234  0.827766

# %%
ev.print_full_df_column(most_incorrect, ['candidate_task', 'label'], True)
# Out:
# candidate_task	label
# ENA Origination Support (Getting info from Tycholiz)--$$XXK	neg
# wanted only to buy and sell conventional reinsurance, Mr. Sweeney	neg
# end, after court hearings on the issue, the Drexel estate	neg
# the market observations (as opposed to historical data).	neg
# late Tuesday accused 29 Enron officers and directors of	neg
# John Elder, creator of a grass-roots investment program to develop	neg
# Managing Director, Enterprise Risk	neg
# use the	neg
# 2. Decision support system: a model recommending transactions to a trader without	neg
# Published: June 2000	neg
# "payments as necessary ""in order to protect and maintain the"	neg
# prove - then the judge can void the payments and order the	neg
# 3. Fully automated trading system, setting prices and executing trades on an electronic trading platform.	neg
# to petition the bankruptcy court to cash in unused vacation	neg
# massive directional trading and representing huge risks to investors. One way to counter this	neg
# contracts based on cold weather.	neg
# 13 files sent for R (public version of S).	neg
# Key risks associated with each category:	neg
# bonuses to about 500 employees, according to several people	neg
# Please note your account 00235424-0015	neg

# %% [markdown]
# ### Manual annotations
#
# **candidate\_task**|**label**|**annotation**
# :-----:|:-----:|:-----:
# ENA Origination Support (Getting info from Tycholiz)--$$XXK|neg|[3(VBG)]
# New York Times on the Web, please contact Alyson|neg|[1]
# Racer at alyson@nytimes.com or visit our online media|neg|[1]
# wanted only to buy and sell conventional reinsurance, Mr. Sweeney|neg|[3(VBD;VB;VB)]
# visit http://www.adamsmark.com/resv/rescheck.html.|neg|[1]
# freeze: bridge|neg|[1]
# use the following link for enrononline: www.enrononline.com|neg|[1]
# end, after court hearings on the issue, the Drexel estate|neg|[2]
# seek to buy replacement coverage to offset depletions in their|neg|[1][2]
# For general information about NYTimes.com, write to|neg|[1][2]
# the market observations (as opposed to historical data).|neg|[3(VBN)]
# execute the agreement and return it to me via fax no. (713) 646-3490.  I will|neg|[1]
# bring these issues to the table, in a meeting involving all the concerned parties|neg|[1]
# late Tuesday accused 29 Enron officers and directors of|neg|[2][3(VBD)]
# John Elder, creator of a grass-roots investment program to develop|neg|[2][3(VB)]
# Get FREE shipping on orders of $75 or more at Starbucks.com|neg|[1]
# Managing Director, Enterprise Risk|neg|[3(VBG)]
# use the|neg|[1][2]
# 2. Decision support system: a model recommending transactions to a trader without|neg|[3(VBG)]
# convince the external parties (stock analysts, creditors,  credit rating agencies) about|neg|[1]
#
# **Annotation Key**:
# - [1] = Reasonable task
# - [2] = Sentence fragment
# - [3(\*)] = Overweighted VERB (VB\* forms)
#
#
# ([Markdown Table Generator](https://jakebathman.github.io/Markdown-Table-Generator/))
#
# #### Improvements
# - **#3** Add feature around the specific kind of VERB (present vs past, etc)
# - **#4** Might be useful to classify the greater body of text (e.g., article, paragraph, ?) as something worth further parsing by line - to help avoid sentence fragmentation or pulling "reasonable tasks" out of irrelevant text.

# %%
ev.render_displacy(most_incorrect, ev.DisplacyStyles.dep)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1275" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">ENA</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Origination</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Support (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Getting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">info</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">from</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Tycholiz)--$$XXK</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,179.0 L578.0,167.0 562.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,179.0 L928.0,167.0 912.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,179.0 L1103.0,167.0 1087.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# ['NNP', 'NNP', 'NNP', '-LRB-', 'VBG', 'NN', 'IN', 'NN']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1800" height="487.0" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">wanted</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">only</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">buy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">sell</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">conventional</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">reinsurance,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Mr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">Sweeney</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M70,352.0 C70,89.5 570.0,89.5 570.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,354.0 L578.0,342.0 562.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,354.0 L743.0,342.0 727.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,354.0 L923.0,342.0 907.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M1120,352.0 C1120,264.5 1260.0,264.5 1260.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M945,352.0 C945,177.0 1265.0,177.0 1265.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1265.0,354.0 L1273.0,342.0 1257.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-7" stroke-width="2px" d="M1470,352.0 C1470,264.5 1610.0,264.5 1610.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1470,354.0 L1462,342.0 1478,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-8" stroke-width="2px" d="M70,352.0 C70,2.0 1625.0,2.0 1625.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-8" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1625.0,354.0 L1633.0,342.0 1617.0,342.0" fill="currentColor"/>
# </g>
# </svg>
# ['VBD', 'RB', 'TO', 'VB', 'CC', 'VB', 'JJ', 'NN', ',', 'NNP', 'NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1800" height="399.5" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">end,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">after</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">court</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">hearings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">issue,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">Drexel</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">estate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M215.0,266.5 L223.0,254.5 207.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,266.5 L578.0,254.5 562.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M770,264.5 C770,89.5 1095.0,89.5 1095.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,266.5 L1103.0,254.5 1087.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M1295,264.5 C1295,89.5 1620.0,89.5 1620.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,266.5 L1287,254.5 1303,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-7" stroke-width="2px" d="M1470,264.5 C1470,177.0 1615.0,177.0 1615.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1470,266.5 L1462,254.5 1478,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-8" stroke-width="2px" d="M70,264.5 C70,2.0 1625.0,2.0 1625.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-8" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1625.0,266.5 L1633.0,254.5 1617.0,254.5" fill="currentColor"/>
# </g>
# </svg>
# ['VB', ',', 'IN', 'NN', 'NNS', 'IN', 'DT', 'NN', ',', 'DT', 'NNP', 'NN']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1450" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">market</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">observations (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">opposed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">historical</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">data).</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">mark</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,179.0 L587,167.0 603,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M420,177.0 C420,2.0 750.0,2.0 750.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">parataxis</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,179.0 L758.0,167.0 742.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,179.0 L928.0,167.0 912.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M1120,177.0 C1120,89.5 1270.0,89.5 1270.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,179.0 L1112,167.0 1128,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M945,177.0 C945,2.0 1275.0,2.0 1275.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1275.0,179.0 L1283.0,167.0 1267.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# ['DT', 'NN', 'NNS', '-LRB-', 'IN', 'VBN', 'IN', 'JJ', 'NNS', '-RRB-', '.']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1625" height="487.0" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">late</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Tuesday</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">accused</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">29</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Enron</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">officers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">directors</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,352.0 C245,264.5 385.0,264.5 385.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,354.0 L237,342.0 253,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M420,352.0 C420,89.5 920.0,89.5 920.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,354.0 L928.0,342.0 912.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1085.0,354.0 L1093.0,342.0 1077.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M945,352.0 C945,177.0 1265.0,177.0 1265.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1265.0,354.0 L1273.0,342.0 1257.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-7" stroke-width="2px" d="M420,352.0 C420,2.0 1450.0,2.0 1450.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1450.0,354.0 L1458.0,342.0 1442.0,342.0" fill="currentColor"/>
# </g>
# </svg>
# ['JJ', 'NNP', 'VBD', 'CD', 'NNP', 'NNS', 'CC', 'NNS', 'IN']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1975" height="574.5" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">John</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Elder,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">creator</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">grass-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">roots</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">investment</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">program</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">develop</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M380.0,441.5 L388.0,429.5 372.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M420,439.5 C420,352.0 555.0,352.0 555.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M555.0,441.5 L563.0,429.5 547.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M770,439.5 C770,177.0 1440.0,177.0 1440.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,441.5 L937,429.5 953,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M1120,439.5 C1120,264.5 1435.0,264.5 1435.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,441.5 L1112,429.5 1128,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M1295,439.5 C1295,352.0 1430.0,352.0 1430.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,441.5 L1287,429.5 1303,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-7" stroke-width="2px" d="M595,439.5 C595,89.5 1445.0,89.5 1445.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1445.0,441.5 L1453.0,429.5 1437.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-8" stroke-width="2px" d="M1645,439.5 C1645,352.0 1780.0,352.0 1780.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-8" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1645,441.5 L1637,429.5 1653,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-9" stroke-width="2px" d="M245,439.5 C245,2.0 1800.0,2.0 1800.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-9" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">relcl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1800.0,441.5 L1808.0,429.5 1792.0,429.5" fil
# ['NNP', 'NNP', ',', 'NN', 'IN', 'DT', 'NN', 'HYPH', 'NNS', 'NN', 'NN', 'TO', 'VB']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="750" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Managing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Director,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Enterprise</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Risk</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# ['VBG', 'NNP', ',', 'NN', 'NN']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">use</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M225.0,91.5 L233.0,79.5 217.0,79.5" fill="currentColor"/>
# </g>
# </svg>
# ['VB', 'DT']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="2150" height="399.5" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">2.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Decision</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">support</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">system:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">model</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">recommending</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">transactions</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">trader</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">without</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADP</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
# ...
#     </text>
#     <path class="displacy-arrowhead" d="M1270.0,179.0 L1278.0,167.0 1262.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-7" stroke-width="2px" d="M1295,177.0 C1295,89.5 1445.0,89.5 1445.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1445.0,179.0 L1453.0,167.0 1437.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# ['CD', 'NNS', 'VBN', 'IN', 'NN', '-LRB-', 'JJ', 'NN', 'IN', 'NNP', '-RRB-', '.']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1100" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Key</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">risks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">associated</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">each</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">category:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">acl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,179.0 L403.0,167.0 387.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,179.0 L578.0,167.0 562.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M595,177.0 C595,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# ['JJ', 'NNS', 'VBN', 'IN', 'DT', 'NN', ':']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1625" height="487.0" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">bonuses</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">500</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">employees,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">according</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">several</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M210.0,354.0 L218.0,342.0 202.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M595,352.0 C595,264.5 735.0,264.5 735.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,354.0 L587,342.0 603,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M245,352.0 C245,89.5 745.0,89.5 745.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,354.0 L753.0,342.0 737.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M70,352.0 C70,2.0 925.0,2.0 925.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,354.0 L933.0,342.0 917.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M945,352.0 C945,264.5 1085.0,264.5 1085.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1085.0,354.0 L1093.0,342.0 1077.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M1295,352.0 C1295,264.5 1435.0,264.5 1435.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-7" stroke-width="2px" d="M1120,352.0 C1120,177.0 1440.0,177.0 1440.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-7" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1440.0,354.0 L1448.0,342.0 1432.0,342.0" fill="currentColor"/>
# </g>
# </svg>
# ['NNS', 'IN', 'RB', 'CD', 'NNS', ',', 'VBG', 'IN', 'JJ', 'NNS']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1100" height="399.5" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Please</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">note</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">your</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">account</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">00235424-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">0015</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">intj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,266.5 L62,254.5 78,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570.0,266.5 L578.0,254.5 562.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M245,264.5 C245,2.0 750.0,2.0 750.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,266.5 L758.0,254.5 742.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M770,264.5 C770,177.0 915.0,177.0 915.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,266.5 L923.0,254.5 907.0,254.5" fill="currentColor"/>
# </g>
# </svg>
# ['UH', 'VB', 'PRP$', 'NN', 'CD', 'HYPH', 'CD']
# -----

# %%
most_incorrect_pos = ev.get_sample_predictions(preds_df, sample_type=ev.SamplePredictions.MOST_INCORRECT_POS, n=20)
most_incorrect_pos
# Out:
#                      candidate_task                  prob_dist label  \
# 248  I need your dues by COB today!  <ProbDist with 2 samples>   pos
#
#                                               features pred  pos_dist  \
# 248  {'VERB': 1, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  neg   0.44212
#
#      neg_dist  max_dist
# 248   0.55788   0.55788

# %% [markdown]
# **Minor observation**: I've experimented with "commitment" and "request" models trained on email data that would have easily labeled this correctly.

# %%
most_correct = ev.get_sample_predictions(preds_df, sample_type=ev.SamplePredictions.MOST_CORRECT, n=20)
most_correct
# Out:
#                                          candidate_task  \
# 83    5. A shark is the only fish that can blink wit...
# 894   Currently, the trading that is taking place ty...
# 109   cop and Ernie the taxi driver in Frank Capra's...
# 612    The tulips are too excitable, it is winter here.
# 1045  Another aspect of this problem is prioritizati...
# 1001  The most beautiful thing we can experience is ...
# 121   35. "Stewardesses" is the longest word that is...
# 1027  trading desks is perfect. One problem that is ...
# 1000    Imagination is more important than knowledge...
# 1032  One way to address the problem is to implement...
# 1038  What is missing is the industrial type process...
# 88                        building is an American flag.
# 1267  The old man steps up to the tee and hits the b...
# 726   2. I have received another resume that looks v...
# 1393  trying were what actually did it.  Seems that ...
# 1395  Now this one is actually the result of extra g...
# 645   It is what the dead close on, finally; I imagi...
# 1024  One immediate improvement: we should review in...
# 104      20. An ostrich's eye is bigger than its brain.
# 992   I never think of the future - it comes soon en...
#
#                       prob_dist label  \
# 83    <ProbDist with 2 samples>   neg
# 894   <ProbDist with 2 samples>   neg
# 109   <ProbDist with 2 samples>   neg
# 612   <ProbDist with 2 samples>   neg
# 1045  <ProbDist with 2 samples>   neg
# 1001  <ProbDist with 2 samples>   neg
# 121   <ProbDist with 2 samples>   neg
# 1027  <ProbDist with 2 samples>   neg
# 1000  <ProbDist with 2 samples>   neg
# 1032  <ProbDist with 2 samples>   neg
# 1038  <ProbDist with 2 samples>   neg
# 88    <ProbDist with 2 samples>   neg
# 1267  <ProbDist with 2 samples>   neg
# 726   <ProbDist with 2 samples>   neg
# 1393  <ProbDist with 2 samples>   neg
# 1395  <ProbDist with 2 samples>   neg
# 645   <ProbDist with 2 samples>   neg
# 1024  <ProbDist with 2 samples>   neg
# 104   <ProbDist with 2 samples>   neg
# 992   <ProbDist with 2 samples>   neg
#
#                                                features pred  pos_dist  \
# 83    {'VERB': 2, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  neg  0.021730
# 894   {'VERB': 3, 'FOLLOWING_POS_VERB': 1, 'FOLLOWIN...  neg  0.022262
# 109   {'VERB': 1, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  neg  0.022798
# 612   {'VERB': 2, 'FOLLOWING_POS_ADV': 1, 'FOLLOWING...  neg  0.023710
# 1045  {'VERB': 1, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...  neg  0.026688
# 1001  {'VERB': 3, 'FOLLOWING_POS_VERB': 1, 'FOLLOWIN...  neg  0.029022
# 121   {'VERB': 3, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  neg  0.030214
# 1027  {'VERB': 3, 'FOLLOWING_POS_ADJ': 2, 'FOLLOWING...  neg  0.033225
# 1000  {'VERB': 1, 'FOLLOWING_POS_ADV': 1, 'FOLLOWING...  neg  0.034947
# 1032  {'VERB': 4, 'FOLLOWING_POS_DET': 2, 'FOLLOWING...  neg  0.035199
# 1038  {'VERB': 4, 'FOLLOWING_POS_VERB': 2, 'FOLLOWIN...  neg  0.036539
# 88    {'VERB': 1, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  neg  0.039922
# 1267  {'VERB': 3, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  neg  0.043384
# 726   {'VERB': 4, 'FOLLOWING_POS_VERB': 1, 'FOLLOWIN...  neg  0.046644
# 1393  {'VERB': 5, 'FOLLOWING_POS_VERB': 1, 'FOLLOWIN...  neg  0.047420
# 1395  {'VERB': 1, 'FOLLOWING_POS_ADV': 1, 'FOLLOWING...  neg  0.047861
# 645   {'VERB': 2, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...  neg  0.047890
# 1024  {'VERB': 3, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...  neg  0.048629
# 104   {'VERB': 1, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  neg  0.049213
# 992   {'VERB': 2, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  neg  0.049344
#
#       neg_dist  max_dist
# 83    0.978270  0.978270
# 894   0.977738  0.977738
# 109   0.977202  0.977202
# 612   0.976290  0.976290
# 1045  0.973312  0.973312
# 1001  0.970978  0.970978
# 121   0.969786  0.969786
# 1027  0.966775  0.966775
# 1000  0.965053  0.965053
# 1032  0.964801  0.964801
# 1038  0.963461  0.963461
# 88    0.960078  0.960078
# 1267  0.956616  0.956616
# 726   0.953356  0.953356
# 1393  0.952580  0.952580
# 1395  0.952139  0.952139
# 645   0.952110  0.952110
# 1024  0.951371  0.951371
# 104   0.950787  0.950787
# 992   0.950656  0.950656

# %%
ev.print_full_df_column(most_correct, ['candidate_task', 'label'], True)
# Out:
# candidate_task	label
# 5. A shark is the only fish that can blink with both eyes.	neg
# Currently, the trading that is taking place typically involves	neg
# "cop and Ernie the taxi driver in Frank Capra's ""It's a Wonderful Life."""	neg
# The tulips are too excitable, it is winter here.	neg
# Another aspect of this problem is prioritization of different projects. In my view	neg
# "The most beautiful thing we can experience is the mysterious.  It is	neg
# the source of all true art and science."	neg
# "35. ""Stewardesses"" is the longest word that is typed with only the left"	neg
# trading desks is perfect. One problem that is persistent in some portfolios is the disconnect	neg
# Imagination is more important than knowledge...	neg
# One way to address the problem is to implement a module that compares systematically	neg
# What is missing is the industrial type process that guarantees the quality	neg
# building is an American flag.	neg
# The old man steps up to the tee and hits the ball. It goes sailing	neg
# 2. I have received another resume that looks very promising. I am	neg
# trying were what actually did it.  Seems that if you copy from Netscape and	neg
# Now this one is actually the result of extra geek effort on my part.	neg
# It is what the dead close on, finally; I imagine them	neg
# One immediate improvement: we should review inputs that are not based on the trading desks	neg
# 20. An ostrich's eye is bigger than its brain.	neg
# I never think of the future - it comes soon enough.	neg

# %%
most_correct_pos = ev.get_sample_predictions(preds_df, sample_type=ev.SamplePredictions.MOST_CORRECT_POS, n=20)
most_correct_pos
# Out:
#                                          candidate_task  \
# 1134   New York Times on the Web, please contact Alyson
# 1517  install v4.0 build 23, follow old instructions...
# 1135  Racer at alyson@nytimes.com or visit our onlin...
# 273   Check last years tax return for RRSP contribut...
# 33    visit http://www.adamsmark.com/resv/rescheck.h...
# 1255                     Call Ambrosia ? Monday morning
# 1328                                     freeze: bridge
# 605                                 Send ED-mail to Ed.
# 1280  use the following link for enrononline: www.en...
# 163                                        Check for ML
# 127   Set up a folder on the C-drive called WINZIP a...
# 603                                  Send E-mail to Ed.
# 1516            please download and make a backup copy.
# 948   seek to buy replacement coverage to offset dep...
# 1137  For general information about NYTimes.com, wri...
# 1215                              Call Grant about Tony
# 139   execute the agreement and return it to me via ...
# 1049  bring these issues to the table, in a meeting ...
# 1055  Get FREE shipping on orders of $75 or more at ...
# 75                      resend pheasant email to all.df
#
#                       prob_dist label  \
# 1134  <ProbDist with 2 samples>   pos
# 1517  <ProbDist with 2 samples>   pos
# 1135  <ProbDist with 2 samples>   pos
# 273   <ProbDist with 2 samples>   pos
# 33    <ProbDist with 2 samples>   pos
# 1255  <ProbDist with 2 samples>   pos
# 1328  <ProbDist with 2 samples>   pos
# 605   <ProbDist with 2 samples>   pos
# 1280  <ProbDist with 2 samples>   pos
# 163   <ProbDist with 2 samples>   pos
# 127   <ProbDist with 2 samples>   pos
# 603   <ProbDist with 2 samples>   pos
# 1516  <ProbDist with 2 samples>   pos
# 948   <ProbDist with 2 samples>   pos
# 1137  <ProbDist with 2 samples>   pos
# 1215  <ProbDist with 2 samples>   pos
# 139   <ProbDist with 2 samples>   pos
# 1049  <ProbDist with 2 samples>   pos
# 1055  <ProbDist with 2 samples>   pos
# 75    <ProbDist with 2 samples>   pos
#
#                                                features pred  pos_dist  \
# 1134  {'VERB': 1, 'FOLLOWING_POS_PROPN': 1, 'FOLLOWI...  pos  0.938270
# 1517  {'VERB': 4, 'FOLLOWING_POS_NOUN': 3, 'FOLLOWIN...  pos  0.937159
# 1135  {'VERB': 1, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.933680
# 273   {'VERB': 1, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.923122
# 33    {'VERB': 1, 'FOLLOWING_POS_PROPN': 1, 'FOLLOWI...  pos  0.912509
# 1255  {'VERB': 1, 'FOLLOWING_POS_PROPN': 1, 'FOLLOWI...  pos  0.912509
# 1328  {'VERB': 1, 'FOLLOWING_POS_PUNCT': 1, 'FOLLOWI...  pos  0.911395
# 605   {'VERB': 1, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...  pos  0.910623
# 1280  {'VERB': 2, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  pos  0.908801
# 163   {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.905871
# 127   {'VERB': 4, 'FOLLOWING_POS_PART': 1, 'FOLLOWIN...  pos  0.904842
# 603   {'VERB': 1, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...  pos  0.902484
# 1516  {'VERB': 2, 'FOLLOWING_POS_CCONJ': 1, 'FOLLOWI...  pos  0.899506
# 948   {'VERB': 3, 'FOLLOWING_POS_PART': 1, 'FOLLOWIN...  pos  0.888222
# 1137  {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.882803
# 1215  {'VERB': 1, 'FOLLOWING_POS_PROPN': 1, 'FOLLOWI...  pos  0.881632
# 139   {'VERB': 2, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  pos  0.881450
# 1049  {'VERB': 2, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  pos  0.881149
# 1055  {'VERB': 1, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.878127
# 75    {'VERB': 2, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.874347
#
#       neg_dist  max_dist
# 1134  0.061730  0.938270
# 1517  0.062841  0.937159
# 1135  0.066320  0.933680
# 273   0.076878  0.923122
# 33    0.087491  0.912509
# 1255  0.087491  0.912509
# 1328  0.088605  0.911395
# 605   0.089377  0.910623
# 1280  0.091199  0.908801
# 163   0.094129  0.905871
# 127   0.095158  0.904842
# 603   0.097516  0.902484
# 1516  0.100494  0.899506
# 948   0.111778  0.888222
# 1137  0.117197  0.882803
# 1215  0.118368  0.881632
# 139   0.118550  0.881450
# 1049  0.118851  0.881149
# 1055  0.121873  0.878127
# 75    0.125653  0.874347

# %%
most_uncertain = ev.get_sample_predictions(preds_df, sample_type=ev.SamplePredictions.MOST_UNCERTAIN, n=20)
most_uncertain
# Out:
#                                          candidate_task  \
# 648   Even through the gift paper I could hear them ...
# 727   very interested in this guy and would be ready...
# 1108  to certain employees, and not proceed with the...
# 1097  up as to whether there was fair consideration ...
# 559   Freeman indicated that the Power Authority has...
# 786   For your convenience, this workshop will be he...
# 998   You cannot simultaneously prevent and prepare ...
# 903   of Trade, which began trading the options in 1...
# 380           maine impossible to get to...next option?
# 632   Their smiles catch onto my skin, little smilin...
# 1394  paste into this e-mail system it happens autom...
# 959   a mild winter, and it would be able to use the...
# 772        Keeping it all together, through the change.
# 594              tmpl_name=stock_quote.html&ticker=mksi
# 636   Scared and bare on the green plastic-pillowed ...
# 667      Playing and resting without committing itself.
# 811   3. Next to equity investment, they would like ...
# 64    dept. I also perform various clerical duties s...
# 402   Transwestern is either considering, or in the ...
# 1065  Yesterday evening, an Enron spokesman confirme...
#
#                       prob_dist label  \
# 648   <ProbDist with 2 samples>   neg
# 727   <ProbDist with 2 samples>   neg
# 1108  <ProbDist with 2 samples>   neg
# 1097  <ProbDist with 2 samples>   neg
# 559   <ProbDist with 2 samples>   neg
# 786   <ProbDist with 2 samples>   neg
# 998   <ProbDist with 2 samples>   neg
# 903   <ProbDist with 2 samples>   neg
# 380   <ProbDist with 2 samples>   pos
# 632   <ProbDist with 2 samples>   neg
# 1394  <ProbDist with 2 samples>   neg
# 959   <ProbDist with 2 samples>   neg
# 772   <ProbDist with 2 samples>   neg
# 594   <ProbDist with 2 samples>   neg
# 636   <ProbDist with 2 samples>   neg
# 667   <ProbDist with 2 samples>   neg
# 811   <ProbDist with 2 samples>   neg
# 64    <ProbDist with 2 samples>   neg
# 402   <ProbDist with 2 samples>   neg
# 1065  <ProbDist with 2 samples>   neg
#
#                                                features pred  pos_dist  \
# 648   {'VERB': 2, 'FOLLOWING_POS_PRON': 1, 'FOLLOWIN...  neg  0.499242
# 727   {'VERB': 2, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.500941
# 1108  {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.502288
# 1097  {'VERB': 2, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.502583
# 559   {'VERB': 5, 'FOLLOWING_POS_ADP': 2, 'FOLLOWING...  pos  0.502932
# 786   {'VERB': 2, 'FOLLOWING_POS_VERB': 1, 'FOLLOWIN...  neg  0.496220
# 998   {'VERB': 2, 'FOLLOWING_POS_CCONJ': 1, 'FOLLOWI...  neg  0.495866
# 903   {'VERB': 2, 'FOLLOWING_POS_VERB': 1, 'FOLLOWIN...  neg  0.493854
# 380   {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.510187
# 632   {'VERB': 2, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.510244
# 1394  {'VERB': 2, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.511163
# 959   {'VERB': 3, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  neg  0.488330
# 772   {'VERB': 1, 'FOLLOWING_POS_PRON': 1, 'FOLLOWIN...  neg  0.487013
# 594   {'VERB': 1, 'PARENT_DEP_ROOT': 1, 'PARENT_POS_...  neg  0.484805
# 636   {'VERB': 1, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...  pos  0.515466
# 667   {'VERB': 3, 'FOLLOWING_POS_CCONJ': 1, 'FOLLOWI...  neg  0.483966
# 811   {'VERB': 2, 'FOLLOWING_POS_PART': 1, 'FOLLOWIN...  pos  0.516555
# 64    {'VERB': 2, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  neg  0.482310
# 402   {'VERB': 3, 'FOLLOWING_POS_CCONJ': 1, 'FOLLOWI...  neg  0.480404
# 1065  {'VERB': 1, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  neg  0.479050
#
#       neg_dist  max_dist
# 648   0.500758  0.500758
# 727   0.499059  0.500941
# 1108  0.497712  0.502288
# 1097  0.497417  0.502583
# 559   0.497068  0.502932
# 786   0.503780  0.503780
# 998   0.504134  0.504134
# 903   0.506146  0.506146
# 380   0.489813  0.510187
# 632   0.489756  0.510244
# 1394  0.488837  0.511163
# 959   0.511670  0.511670
# 772   0.512987  0.512987
# 594   0.515195  0.515195
# 636   0.484534  0.515466
# 667   0.516034  0.516034
# 811   0.483445  0.516555
# 64    0.517690  0.517690
# 402   0.519596  0.519596
# 1065  0.520950  0.520950

# %%
ev.print_full_df_column(most_uncertain, ['candidate_task', 'pred', 'label'], True)
# Out:
# candidate_task	pred	label
# Even through the gift paper I could hear them breathe	neg	neg
# very interested in this guy and would be ready to bring him over	pos	neg
# to certain employees, and not proceed with the payments	pos	neg
# up as to whether there was fair consideration given for the	pos	neg
# Freeman indicated that the Power Authority has signed letters of intent to purchase output from 14 biomass facilities in the Central Valley, as well as 400 MW generated by wind.	pos	neg
# For your convenience, this workshop will be held at three different times	neg	neg
# You cannot simultaneously prevent and prepare for war.	neg	neg
# of Trade, which began trading the options in 1996.	neg	neg
# maine impossible to get to...next option?	pos	pos
# Their smiles catch onto my skin, little smiling hooks.	pos	neg
# paste into this e-mail system it happens automatically.	pos	neg
# a mild winter, and it would be able to use the futures to hedge a	neg	neg
# Keeping it all together, through the change.	neg	neg
# tmpl_name=stock_quote.html&ticker=mksi	neg	neg
# Scared and bare on the green plastic-pillowed trolley	pos	neg
# Playing and resting without committing itself.	neg	neg
# 3. Next to equity investment, they would like to see a constant income stream through	pos	neg
# dept. I also perform various clerical duties such as filing , archiving,	neg	neg
# Transwestern is either considering, or in the early stages of, developing additional pipeline infrastrastructure in California.	neg	neg
# Yesterday evening, an Enron spokesman confirmed the	neg	neg

# %%
ev.confusion_matrix(most_uncertain[['candidate_task', 'prob_dist', 'label', 'features']].itertuples(index=False))
# Out:
# array([[11,  8],
#        [ 0,  1]])

# %% [markdown]
# #### Q: What TP candidates (actual tasks) didn't have features?

# %%
all_correct_pos = ev.get_sample_predictions(preds_df, sample_type=ev.SamplePredictions.MOST_CORRECT_POS)

# %%
len(all_correct_pos)
# Out:
# 96

# %%
no_features_mask = all_correct_pos['features'] == {}
tp_no_features = all_correct_pos.iloc[np.where(no_features_mask)]
tp_no_features
# Out:
#                              candidate_task                  prob_dist label  \
# 746                               McCormack  <ProbDist with 2 samples>   pos
# 747                 Article about the group  <ProbDist with 2 samples>   pos
# 604               Dentist on  Jan 25, 7:45.  <ProbDist with 2 samples>   pos
# 753                              1, Li Xiao  <ProbDist with 2 samples>   pos
# 754                                2. Accom  <ProbDist with 2 samples>   pos
# 1172                      Krishna's letters  <ProbDist with 2 samples>   pos
# 755                      3. Barbara Weather  <ProbDist with 2 samples>   pos
# 764                              10:00  Sat  <ProbDist with 2 samples>   pos
# 984                               Headcount  <ProbDist with 2 samples>   pos
# 1171              EES presentations to Rhys  <ProbDist with 2 samples>   pos
# 597                                Articles  <ProbDist with 2 samples>   pos
# 1234                            exact time.  <ProbDist with 2 samples>   pos
# 1252                                Thanks,  <ProbDist with 2 samples>   pos
# 1253                                     RT  <ProbDist with 2 samples>   pos
# 1485                   Monday at 11:30 Tara  <ProbDist with 2 samples>   pos
# 602               Dentist on  Jan 25, 7:45.  <ProbDist with 2 samples>   pos
# 8                              speed on eol  <ProbDist with 2 samples>   pos
# 596                                   Vince  <ProbDist with 2 samples>   pos
# 527                              1. M. Soto  <ProbDist with 2 samples>   pos
# 286                    $933  to Dean Witter  <ProbDist with 2 samples>   pos
# 276                 - MYERS, JENNIFER M.doc  <ProbDist with 2 samples>   pos
# 275                  - HUSSER, SHANNA L.doc  <ProbDist with 2 samples>   pos
# 274                     - FLINN, DARA M.doc  <ProbDist with 2 samples>   pos
# 184                                $4676.18  <ProbDist with 2 samples>   pos
# 183                                To Keith  <ProbDist with 2 samples>   pos
# 182                                 $20,709  <ProbDist with 2 samples>   pos
# 181                                To Keith  <ProbDist with 2 samples>   pos
# 180                                 3.Steve  <ProbDist with 2 samples>   pos
# 179                          2. John Martin  <ProbDist with 2 samples>   pos
# 178                         1. Presentation  <ProbDist with 2 samples>   pos
# 177          Call John Martin Sat 3:00 p.m.  <ProbDist with 2 samples>   pos
# 162                             Phone cards  <ProbDist with 2 samples>   pos
# 128                 files into that folder.  <ProbDist with 2 samples>   pos
# 126                                  Danny,  <ProbDist with 2 samples>   pos
# 76                                     memo  <ProbDist with 2 samples>   pos
# 11                        dave or tom moran  <ProbDist with 2 samples>   pos
# 341                    Outline for Stinson.  <ProbDist with 2 samples>   pos
# 378   Power 2000 Operational Risk for Kevin  <ProbDist with 2 samples>   pos
# 379                                rent tix  <ProbDist with 2 samples>   pos
# 483                                  Lacima  <ProbDist with 2 samples>   pos
# 499                            1. Ecopetrol  <ProbDist with 2 samples>   pos
# 490                                  Piazze  <ProbDist with 2 samples>   pos
# 489                                Johansen  <ProbDist with 2 samples>   pos
# 9                        message for monday  <ProbDist with 2 samples>   pos
# 487                            Andy kalotay  <ProbDist with 2 samples>   pos
# 486                    2. Rosemary  at ICBI  <ProbDist with 2 samples>   pos
# 485                   1. Paper fro Kevin K.  <ProbDist with 2 samples>   pos
# 482                             Nelson Neal  <ProbDist with 2 samples>   pos
# 481                                   Donna  <ProbDist with 2 samples>   pos
# 480                 Rosemary - presentation  <ProbDist with 2 samples>   pos
# 458                                     B&C  <ProbDist with 2 samples>   pos
# 457                  Josie  2:00 p.m.   wed  <ProbDist with 2 samples>   pos
# 445                       Interview for Lee  <ProbDist with 2 samples>   pos
# 410                                283-7561  <ProbDist with 2 samples>   pos
# 409                           Jean Cummings  <ProbDist with 2 samples>   pos
# 488                               Brad Horn  <ProbDist with 2 samples>   pos
#
#      features pred  pos_dist  neg_dist  max_dist
# 746        {}  pos  0.560698  0.439302  0.560698
# 747        {}  pos  0.560698  0.439302  0.560698
# 604        {}  pos  0.560698  0.439302  0.560698
# 753        {}  pos  0.560698  0.439302  0.560698
# 754        {}  pos  0.560698  0.439302  0.560698
# 1172       {}  pos  0.560698  0.439302  0.560698
# 755        {}  pos  0.560698  0.439302  0.560698
# 764        {}  pos  0.560698  0.439302  0.560698
# 984        {}  pos  0.560698  0.439302  0.560698
# 1171       {}  pos  0.560698  0.439302  0.560698
# 597        {}  pos  0.560698  0.439302  0.560698
# 1234       {}  pos  0.560698  0.439302  0.560698
# 1252       {}  pos  0.560698  0.439302  0.560698
# 1253       {}  pos  0.560698  0.439302  0.560698
# 1485       {}  pos  0.560698  0.439302  0.560698
# 602        {}  pos  0.560698  0.439302  0.560698
# 8          {}  pos  0.560698  0.439302  0.560698
# 596        {}  pos  0.560698  0.439302  0.560698
# 527        {}  pos  0.560698  0.439302  0.560698
# 286        {}  pos  0.560698  0.439302  0.560698
# 276        {}  pos  0.560698  0.439302  0.560698
# 275        {}  pos  0.560698  0.439302  0.560698
# 274        {}  pos  0.560698  0.439302  0.560698
# 184        {}  pos  0.560698  0.439302  0.560698
# 183        {}  pos  0.560698  0.439302  0.560698
# 182        {}  pos  0.560698  0.439302  0.560698
# 181        {}  pos  0.560698  0.439302  0.560698
# 180        {}  pos  0.560698  0.439302  0.560698
# 179        {}  pos  0.560698  0.439302  0.560698
# 178        {}  pos  0.560698  0.439302  0.560698
# 177        {}  pos  0.560698  0.439302  0.560698
# 162        {}  pos  0.560698  0.439302  0.560698
# 128        {}  pos  0.560698  0.439302  0.560698
# 126        {}  pos  0.560698  0.439302  0.560698
# 76         {}  pos  0.560698  0.439302  0.560698
# 11         {}  pos  0.560698  0.439302  0.560698
# 341        {}  pos  0.560698  0.439302  0.560698
# 378        {}  pos  0.560698  0.439302  0.560698
# 379        {}  pos  0.560698  0.439302  0.560698
# 483        {}  pos  0.560698  0.439302  0.560698
# 499        {}  pos  0.560698  0.439302  0.560698
# 490        {}  pos  0.560698  0.439302  0.560698
# 489        {}  pos  0.560698  0.439302  0.560698
# 9          {}  pos  0.560698  0.439302  0.560698
# 487        {}  pos  0.560698  0.439302  0.560698
# 486        {}  pos  0.560698  0.439302  0.560698
# 485        {}  pos  0.560698  0.439302  0.560698
# 482        {}  pos  0.560698  0.439302  0.560698
# 481        {}  pos  0.560698  0.439302  0.560698
# 480        {}  pos  0.560698  0.439302  0.560698
# 458        {}  pos  0.560698  0.439302  0.560698
# 457        {}  pos  0.560698  0.439302  0.560698
# 445        {}  pos  0.560698  0.439302  0.560698
# 410        {}  pos  0.560698  0.439302  0.560698
# 409        {}  pos  0.560698  0.439302  0.560698
# 488        {}  pos  0.560698  0.439302  0.560698

# %% [markdown]
# **Improvement #5**: Manual re-labeling due to my "split by new line" decision is necessary for more accurate results. All sample datasets have instances of mis-labeled data.

# %%
ev.render_displacy(tp_no_features, [ev.DisplacyStyles.dep, ev.DisplacyStyles.ent])
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">McCormack</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
# </svg>
# <div class="entities" style="line-height: 2.5">McCormack</div>
# ['NN']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="750" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Article</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">about</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">group</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220.0,179.0 L228.0,167.0 212.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">Article about the group</div>
# ['NN', 'IN', 'DT', 'NN']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1100" height="399.5" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Dentist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Jan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">25,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">7:45.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M215.0,266.5 L223.0,254.5 207.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390.0,266.5 L398.0,254.5 382.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,266.5 L583.0,254.5 567.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">Dentist on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#      Jan 25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     7:45
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# .</div>
# ['NN', 'IN', '', 'NNP', 'CD', ',', 'CD', '.']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="575" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">1,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Li</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Xiao</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,179.0 L237,167.0 253,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,179.0 L408.0,167.0 392.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Li Xiao
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div>
# ['LS', ',', 'NNP', 'NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">2.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">Accom</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">X</tspan>
# </text>
# </svg>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . Accom</div>
# ['LS', '.', 'ADD']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="575" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Krishna</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">letters</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220.0,179.0 L228.0,167.0 212.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Krishna
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 's letters</div>
# ['NNP', 'POS', 'NNS']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="575" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">3.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Barbara</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Weather</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,91.5 L237,79.5 253,79.5" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Barbara Weather
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div>
# ['LS', '.', 'NNP', 'NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="575" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">10:00</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">Sat</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,2.0 400.0,2.0 400.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220.0,179.0 L228.0,167.0 212.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     10:00  Sat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# </div>
# ['CD', '', 'NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Headcount</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
# </svg>
# <div class="entities" style="line-height: 2.5">Headcount</div>
# ['NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="750" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">EES</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">presentations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Rhys</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,91.5 L408.0,79.5 392.0,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M420,89.5 C420,2.0 575.0,2.0 575.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,91.5 L583.0,79.5 567.0,79.5" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">EES presentations to
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Rhys
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div>
# ['NNP', 'NNS', 'IN', 'NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Articles</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
# </svg>
# <div class="entities" style="line-height: 2.5">Articles</div>
# ['NNS']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">exact</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">time.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">exact time.</div>
# ['JJ', 'NN', '.']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Thanks,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
# </svg>
# <div class="entities" style="line-height: 2.5">Thanks,</div>
# ['NNS', ',']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">RT</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
# </svg>
# <div class="entities" style="line-height: 2.5">RT</div>
# ['NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="750" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Monday</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">at</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">11:30</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">Tara</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220.0,179.0 L228.0,167.0 212.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,179.0 L403.0,167.0 387.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M70,177.0 C70,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     11:30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  Tara</div>
# ['NNP', 'IN', 'CD', 'NN']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1100" height="399.5" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Dentist</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Jan</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">25,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">7:45.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,264.5 C70,177.0 215.0,177.0 215.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M215.0,266.5 L223.0,254.5 207.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,264.5 C245,177.0 390.0,177.0 390.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M390.0,266.5 L398.0,254.5 382.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,266.5 L583.0,254.5 567.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M595,264.5 C595,89.5 920.0,89.5 920.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M920.0,266.5 L928.0,254.5 912.0,254.5" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">Dentist on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#      Jan 25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     7:45
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# .</div>
# ['NN', 'IN', '', 'NNP', 'CD', ',', 'CD', '.']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="575" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">speed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">eol</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M225.0,91.5 L233.0,79.5 217.0,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,91.5 L408.0,79.5 392.0,79.5" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">speed on eol</div>
# ['NN', 'IN', 'NN']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Vince</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
# </svg>
# <div class="entities" style="line-height: 2.5">Vince</div>
# ['NN']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="575" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">1.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">M.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Soto</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,91.5 L237,79.5 253,79.5" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# .
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     M. Soto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div>
# ['LS', '.', 'NNP', 'NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1100" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">$</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SYM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">933</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Dean</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">Witter</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,177.0 C245,89.5 395.0,89.5 395.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M395.0,179.0 L403.0,167.0 387.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M595,177.0 C595,2.0 925.0,2.0 925.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M925.0,179.0 L933.0,167.0 917.0,167.0" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">$
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     933
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#   to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Dean Witter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div>
# ['$', 'CD', '', 'IN', 'NNP', 'NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="750" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">MYERS,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">JENNIFER</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">M.doc</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">appos</textPath>
# ...
#     Nelson Neal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div>
# ['NNP', 'NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Donna</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
# </svg>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Donna
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div>
# ['NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Rosemary -</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">presentation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">Rosemary - presentation</div>
# ['JJ', 'HYPH', 'NN']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="225" height="137.0" style="max-width: none; height: 137.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="47.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">B&C</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
# </svg>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     B&C
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div>
# ['NN']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="1275" height="312.0" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Josie</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225"> </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">2:00</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">p.m.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">  </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">we</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">d</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M220.0,179.0 L228.0,167.0 212.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M70,177.0 C70,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M595,177.0 C595,89.5 745.0,89.5 745.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle"></textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,179.0 L753.0,167.0 737.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,179.0 L937,167.0 953,167.0" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">Josie
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2:00 p.m.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# wed</div>
# ['NNP', '', 'CD', 'NN', '_SP', 'PRP', 'MD']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="575" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Interview</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">Lee</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M225.0,91.5 L233.0,79.5 217.0,79.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M245,89.5 C245,2.0 400.0,2.0 400.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400.0,91.5 L408.0,79.5 392.0,79.5" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">Interview for
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div>
# ['NN', 'IN', 'NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">283-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">7561</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NUM</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M225.0,91.5 L233.0,79.5 217.0,79.5" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     283
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# -7561</div>
# ['CD', 'SYM', 'CD']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Jean</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Cummings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jean Cummings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div>
# ['NNP', 'NNP']
# -----
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="400" height="224.5" style="max-width: none; height: 224.5px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Brad</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="134.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Horn</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,89.5 C70,2.0 225.0,2.0 225.0,89.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,91.5 L62,79.5 78,79.5" fill="currentColor"/>
# </g>
# </svg>
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Brad Horn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div>
# ['NNP', 'NNP']
# -----

# %% [markdown]
# ### Observations
#
# - Model is bad at:
#     - Incomplete sentences/fragments
#     - Tasks without verbs (noun phrases)
#     - Taking verb tense into account
# - Model is good at:
#     - Finding tasks in weird contexts
# - Model is most uncertain about:

# %% [markdown]
# ## Writing: get_sample_predictions
#
# Understanding code from [fast.ai 2018: lesson 1](https://github.com/fastai/fastai/blob/master/courses/dl1/lesson1.ipynb) for getting various types of sample predictions.

# %% [markdown]
# `def rand_by_mask(mask, n): return np.random.choice(np.where(mask)[0], n, replace=False)`
#
#     np.random.choice(a, size=None, replace=True, p=None)
#
#     np.where(condition[, x, y])
#
# `def rand_by_correct(preds, is_correct): return rand_by_mask((preds.preds == preds.labels)==is_correct)`
#
#     np.where((preds.preds == preds.labels)==is_correct))

# %% [markdown]
# Goals:
# 1. Get `preds` into a form so that `rand_by_mask` works on it
# 2. Get `preds` into a form so that we can find what is correct vs incorrect

# %% [markdown]
# ### What is `preds`?

# %%
type(preds)
# Out:
# list

# %%
type(preds[1]), preds[1]
# Out:
# (tuple,
#  ('http://gasfundy.corp.enron.com/gas/framework/default.asp',
#   <ProbDist with 2 samples>,
#   'neg',
#   {}))

# %% [markdown]
# where `tuple == (candidate_task, prediction_dist, label, features)`

# %%
[(p[0], p[1].max(), p[2], p[3]) for p in preds][1]
# Out:
# ('http://gasfundy.corp.enron.com/gas/framework/default.asp', 'pos', 'neg', {})

# %%
type(preds[1][1]), preds[1][1]
# Out:
# (nltk.probability.DictionaryProbDist, <ProbDist with 2 samples>)

# %%
import nltk
??nltk.probability.DictionaryProbDist

# %%
preds[1][1].samples()
# Out:
# dict_keys(['neg', 'pos'])

# %%
preds[1][1].max()
# Out:
# 'pos'

# %%
preds[1][1].prob('pos'), preds[1][1].prob('neg')
# Out:
# (0.56069809800114434, 0.43930190199885577)

# %% [markdown]
# ### Form of `preds` that works with `rand_by_mask(mask, n)`?

# %% [markdown]
# For `np.random.choice`, first arg must be 1-dimensional

# %%
import numpy as np
np_preds = np.array(preds)
np_preds.shape
# Out:
# (1526, 4)

# %% [markdown]
# `preds` as it stands will not work. Instead, we can feed in the length of `preds` and let `np.random.choice` select random indices of `preds`.

# %%
n = 5 # number of results
mask = len(np_preds)

# %%
np_random = np_preds[np.random.choice(mask, n)]

# %%
np_random
# Out:
# array([['http://www.science-finance.fr/publications.html',
#         <ProbDist with 2 samples>, 'neg', {}],
#        ['They pass the way gulls pass inland in their white caps,',
#         <ProbDist with 2 samples>, 'neg',
#         {'VERB': 2, 'FOLLOWING_POS_DET': 1, 'FOLLOWING_POSTAG_DT': 1, 'PARENT_DEP_ROOT': 1, 'PARENT_POS_VERB': 1, 'PARENT_POSTAG_VBP': 1, 'CHILD_DEP_NSUBJ': 2, 'CHILD_POS_PRON': 1, 'CHILD_POSTAG_PRP': 1, 'CHILD_DEP_DOBJ': 1, 'CHILD_POS_NOUN': 2, 'CHILD_POSTAG_NN': 1, 'CHILD_DEP_PUNCT': 1, 'CHILD_POS_PUNCT': 1, 'CHILD_POSTAG_,': 1, 'FOLLOWING_POS_ADV': 1, 'FOLLOWING_POSTAG_RB': 1, 'PARENT_DEP_DOBJ': 1, 'PARENT_POS_NOUN': 1, 'PARENT_POSTAG_NN': 1, 'CHILD_POSTAG_NNS': 1, 'CHILD_DEP_ADVMOD': 1, 'CHILD_POS_ADV': 1, 'CHILD_POSTAG_RB': 1, 'CHILD_DEP_PREP': 1, 'CHILD_POS_ADP': 1, 'CHILD_POSTAG_IN': 1}],
#        ['Houston Chronicle Online', <ProbDist with 2 samples>, 'neg', {}],
#        ['ID:         mcconnellmarkr', <ProbDist with 2 samples>, 'neg', {}],
#        ['https://www.admission.com/html/seatmap.htmI?l=EN&CNTX=23689&C=US',
#         <ProbDist with 2 samples>, 'neg', {}]], dtype=object)

# %%
len(np_random)
# Out:
# 5

# %% [markdown]
# ### Form of `preds` that works with `rand_by_correct(preds, is_correct)`?

# %% [markdown]
# `preds` must be broken down into predictions and labels. So first, let's get the predictions.
#
# Remember that each `tuple` in `preds` == `(candidate_task, prediction_dist, label, features)`

# %%
[p[1].max() for p in preds][:n]
# Out:
# ['pos', 'pos', 'pos', 'pos', 'pos']

# %% [markdown]
# Labels can be retrieved similarly

# %%
[p[2] for p in preds][:n]
# Out:
# ['neg', 'neg', 'neg', 'neg', 'neg']

# %% [markdown]
# Noticing that `preds` might be more readable as a pandas dataframe. So let's convert it.

# %%
import pandas as pd

preds_df = pd.DataFrame.from_records(preds, columns=['candidate_task', 'prob_dist', 'label', 'features'])
preds_df['pred'] = [p.max() for p in preds_df['prob_dist']]

# %%
preds_df[:n]
# Out:
#                                       candidate_task  \
# 0                      https://www4.rsweb.com/61045/
# 1  http://gasfundy.corp.enron.com/gas/framework/d...
# 2                                       212 836 5030
# 3        http://fundamentals.corp.enron.com/main.asp
# 4                                      adams 30  631
#
#                    prob_dist label  \
# 0  <ProbDist with 2 samples>   neg
# 1  <ProbDist with 2 samples>   neg
# 2  <ProbDist with 2 samples>   neg
# 3  <ProbDist with 2 samples>   neg
# 4  <ProbDist with 2 samples>   neg
#
#                                             features pred
# 0                                                 {}  pos
# 1                                                 {}  pos
# 2                                                 {}  pos
# 3                                                 {}  pos
# 4  {'VERB': 1, 'FOLLOWING_POS_NUM': 1, 'FOLLOWING...  pos

# %%
[p.max() for p in preds_df['prob_dist']][:n]
# Out:
# ['pos', 'pos', 'pos', 'pos', 'pos']

# %%
preds_df['label'][:n].values
# Out:
# array(['neg', 'neg', 'neg', 'neg', 'neg'], dtype=object)

# %% [markdown]
# Put this all together to write our own
#
# #### `rand_by_correct(preds, n=5, is_correct=True)`

# %%
def rand_by_mask(mask, n):
    return np.random.choice(np.where(mask)[0], n, replace=False)

def rand_by_correct(preds_df, n = 5, is_correct = True):
    return preds_df.iloc[rand_by_mask(([p.max() for p in preds_df['prob_dist']] == preds_df['label'].values)==is_correct, n)]

# %%
# correct
rand_by_correct(preds_df)
# Out:
#                                          candidate_task  \
# 995   The most incomprehensible thing about the worl...
# 1012  crirticism is to emphasize the quality of Enro...
# 1094  means it probably does become an issue in the ...
# 16    5) In Section 9(a), the non - compete clause i...
# 104      20. An ostrich's eye is bigger than its brain.
#
#                       prob_dist label  \
# 995   <ProbDist with 2 samples>   neg
# 1012  <ProbDist with 2 samples>   neg
# 1094  <ProbDist with 2 samples>   neg
# 16    <ProbDist with 2 samples>   neg
# 104   <ProbDist with 2 samples>   neg
#
#                                                features pred
# 995   {'VERB': 2, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  neg
# 1012  {'VERB': 2, 'FOLLOWING_POS_PART': 1, 'FOLLOWIN...  neg
# 1094  {'VERB': 3, 'FOLLOWING_POS_PRON': 1, 'FOLLOWIN...  neg
# 16    {'VERB': 11, 'FOLLOWING_POS_VERB': 1, 'FOLLOWI...  neg
# 104   {'VERB': 1, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  neg

# %%
# incorrect
rand_by_correct(preds_df, is_correct=False)
# Out:
#                                          candidate_task  \
# 737   for a week to discuss the weather forecasting ...
# 433                                              Feb-04
# 1438                                 ID:         Enr161
# 1164             http://www.stoft.com/x/cal/index.shtml
# 281                                              EB4054
#
#                       prob_dist label  \
# 737   <ProbDist with 2 samples>   neg
# 433   <ProbDist with 2 samples>   neg
# 1438  <ProbDist with 2 samples>   neg
# 1164  <ProbDist with 2 samples>   neg
# 281   <ProbDist with 2 samples>   neg
#
#                                                features pred
# 737   {'VERB': 1, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  pos
# 433                                                  {}  pos
# 1438                                                 {}  pos
# 1164                                                 {}  pos
# 281                                                  {}  pos

# %% [markdown]
# Cool! Adding more goals... this time around getting the 'most correct/incorrect'

# %% [markdown]
# `def most_by_mask(mask, mult):
#     idxs = np.where(mask)[0]
#     return idxs[np.argsort(mult * probs[idxs])[:4]]`
#
#     numpy.argsort(a, axis=-1, kind='quicksort', order=None)
#
# `def most_by_correct(y, is_correct):
#     mult = -1 if (y==1)==is_correct else 1
#     return most_by_mask(((preds == data.val_y)==is_correct) & (data.val_y == y), mult)`
#
#     mult: makes it so that if 'correct' == 'lowest probabilities', the argsort sees lower == more correct. else, higher == more correct

# %% [markdown]
# Goals:
# 1. Get `preds` into a form so that `most_by_mask` works on it
# 2. Get `preds` into a form so that we can find what is _most_ correct vs _most_ incorrect

# %% [markdown]
# Unlike the `Cats vs Dogs` predictions, NLTK provides separate probability distributions for each possible label.
#
# Sorting is easy if we break up the values within the `prob_dist` column

# %%
[p.prob('pos') for p in preds_df['prob_dist']][:n]
# Out:
# [0.56069809800114434,
#  0.56069809800114434,
#  0.56069809800114434,
#  0.56069809800114434,
#  0.59312608626826946]

# %%
[p.prob('neg') for p in preds_df['prob_dist']][:n]
# Out:
# [0.43930190199885577,
#  0.43930190199885577,
#  0.43930190199885577,
#  0.43930190199885577,
#  0.40687391373173049]

# %%
preds_df['pos_dist'] = [p.prob('pos') for p in preds_df['prob_dist']]
preds_df['neg_dist'] = [p.prob('neg') for p in preds_df['prob_dist']]

# %%
preds_df[:n]
# Out:
#                                       candidate_task  \
# 0                      https://www4.rsweb.com/61045/
# 1  http://gasfundy.corp.enron.com/gas/framework/d...
# 2                                       212 836 5030
# 3        http://fundamentals.corp.enron.com/main.asp
# 4                                      adams 30  631
#
#                    prob_dist label  \
# 0  <ProbDist with 2 samples>   neg
# 1  <ProbDist with 2 samples>   neg
# 2  <ProbDist with 2 samples>   neg
# 3  <ProbDist with 2 samples>   neg
# 4  <ProbDist with 2 samples>   neg
#
#                                             features pred  pos_dist  neg_dist
# 0                                                 {}  pos  0.560698  0.439302
# 1                                                 {}  pos  0.560698  0.439302
# 2                                                 {}  pos  0.560698  0.439302
# 3                                                 {}  pos  0.560698  0.439302
# 4  {'VERB': 1, 'FOLLOWING_POS_NUM': 1, 'FOLLOWING...  pos  0.593126  0.406874

# %%
preds_df.sort_values('pos_dist', ascending=False)[:5]
# Out:
#                                          candidate_task  \
# 396   ENA Origination Support (Getting info from Tyc...
# 1134   New York Times on the Web, please contact Alyson
# 1517  install v4.0 build 23, follow old instructions...
# 1135  Racer at alyson@nytimes.com or visit our onlin...
# 926   wanted only to buy and sell conventional reins...
#
#                       prob_dist label  \
# 396   <ProbDist with 2 samples>   neg
# 1134  <ProbDist with 2 samples>   pos
# 1517  <ProbDist with 2 samples>   pos
# 1135  <ProbDist with 2 samples>   pos
# 926   <ProbDist with 2 samples>   neg
#
#                                                features pred  pos_dist  \
# 396   {'VERB': 1, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...  pos  0.973595
# 1134  {'VERB': 1, 'FOLLOWING_POS_PROPN': 1, 'FOLLOWI...  pos  0.938270
# 1517  {'VERB': 4, 'FOLLOWING_POS_NOUN': 3, 'FOLLOWIN...  pos  0.937159
# 1135  {'VERB': 1, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.933680
# 926   {'VERB': 3, 'FOLLOWING_POS_ADV': 1, 'FOLLOWING...  pos  0.928333
#
#       neg_dist
# 396   0.026405
# 1134  0.061730
# 1517  0.062841
# 1135  0.066320
# 926   0.071667

# %%
preds_df.sort_values('neg_dist', ascending=False)[:5]
# Out:
#                                          candidate_task  \
# 83    5. A shark is the only fish that can blink wit...
# 894   Currently, the trading that is taking place ty...
# 109   cop and Ernie the taxi driver in Frank Capra's...
# 612    The tulips are too excitable, it is winter here.
# 1045  Another aspect of this problem is prioritizati...
#
#                       prob_dist label  \
# 83    <ProbDist with 2 samples>   neg
# 894   <ProbDist with 2 samples>   neg
# 109   <ProbDist with 2 samples>   neg
# 612   <ProbDist with 2 samples>   neg
# 1045  <ProbDist with 2 samples>   neg
#
#                                                features pred  pos_dist  \
# 83    {'VERB': 2, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  neg  0.021730
# 894   {'VERB': 3, 'FOLLOWING_POS_VERB': 1, 'FOLLOWIN...  neg  0.022262
# 109   {'VERB': 1, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  neg  0.022798
# 612   {'VERB': 2, 'FOLLOWING_POS_ADV': 1, 'FOLLOWING...  neg  0.023710
# 1045  {'VERB': 1, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...  neg  0.026688
#
#       neg_dist
# 83    0.978270
# 894   0.977738
# 109   0.977202
# 612   0.976290
# 1045  0.973312

# %%
preds[1][1].samples()
# Out:
# dict_keys(['neg', 'pos'])

# %% [markdown]
# Drumroll...
#
# #### most_by_correct(preds_df, label, n=5, is_correct=True)

# %%
def most_by_correct(preds_df, label, n=5, is_correct=True):
    label_options = list(preds_df['prob_dist'][0].samples())
    # note the 2-class assumption
    other_label = label_options[abs(label_options.index(label)-1)]
    # if is_correct, label dist is what matters; if incorrect, look at other_label dist
    dist_column = label + '_dist' if is_correct == True else other_label + '_dist'
    
    correct_mask = ([p.max() for p in preds_df['prob_dist']] == preds_df['label'].values)==is_correct
    target_label_mask = preds_df['label'].values == label
    
    return preds_df.iloc[np.where(correct_mask & target_label_mask)].sort_values(dist_column, ascending=False)[:n]

# %%
most_by_correct(preds_df, 'pos')
# Out:
#                                          candidate_task  \
# 1134   New York Times on the Web, please contact Alyson
# 1517  install v4.0 build 23, follow old instructions...
# 1135  Racer at alyson@nytimes.com or visit our onlin...
# 273   Check last years tax return for RRSP contribut...
# 33    visit http://www.adamsmark.com/resv/rescheck.h...
#
#                       prob_dist label  \
# 1134  <ProbDist with 2 samples>   pos
# 1517  <ProbDist with 2 samples>   pos
# 1135  <ProbDist with 2 samples>   pos
# 273   <ProbDist with 2 samples>   pos
# 33    <ProbDist with 2 samples>   pos
#
#                                                features pred  pos_dist  \
# 1134  {'VERB': 1, 'FOLLOWING_POS_PROPN': 1, 'FOLLOWI...  pos  0.938270
# 1517  {'VERB': 4, 'FOLLOWING_POS_NOUN': 3, 'FOLLOWIN...  pos  0.937159
# 1135  {'VERB': 1, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.933680
# 273   {'VERB': 1, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.923122
# 33    {'VERB': 1, 'FOLLOWING_POS_PROPN': 1, 'FOLLOWI...  pos  0.912509
#
#       neg_dist
# 1134  0.061730
# 1517  0.062841
# 1135  0.066320
# 273   0.076878
# 33    0.087491

# %%
most_by_correct(preds_df, 'neg')
# Out:
#                                          candidate_task  \
# 83    5. A shark is the only fish that can blink wit...
# 894   Currently, the trading that is taking place ty...
# 109   cop and Ernie the taxi driver in Frank Capra's...
# 612    The tulips are too excitable, it is winter here.
# 1045  Another aspect of this problem is prioritizati...
#
#                       prob_dist label  \
# 83    <ProbDist with 2 samples>   neg
# 894   <ProbDist with 2 samples>   neg
# 109   <ProbDist with 2 samples>   neg
# 612   <ProbDist with 2 samples>   neg
# 1045  <ProbDist with 2 samples>   neg
#
#                                                features pred  pos_dist  \
# 83    {'VERB': 2, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  neg  0.021730
# 894   {'VERB': 3, 'FOLLOWING_POS_VERB': 1, 'FOLLOWIN...  neg  0.022262
# 109   {'VERB': 1, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...  neg  0.022798
# 612   {'VERB': 2, 'FOLLOWING_POS_ADV': 1, 'FOLLOWING...  neg  0.023710
# 1045  {'VERB': 1, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...  neg  0.026688
#
#       neg_dist
# 83    0.978270
# 894   0.977738
# 109   0.977202
# 612   0.976290
# 1045  0.973312

# %%
most_by_correct(preds_df, 'pos', is_correct=False)
# Out:
#                      candidate_task                  prob_dist label  \
# 248  I need your dues by COB today!  <ProbDist with 2 samples>   pos
#
#                                               features pred  pos_dist  \
# 248  {'VERB': 1, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  neg   0.44212
#
#      neg_dist
# 248   0.55788

# %%
most_by_correct(preds_df, 'neg', is_correct=False)
# Out:
#                                          candidate_task  \
# 396   ENA Origination Support (Getting info from Tyc...
# 926   wanted only to buy and sell conventional reins...
# 1091  end, after court hearings on the issue, the Dr...
# 1023  the market observations (as opposed to histori...
# 1121  late Tuesday accused 29 Enron officers and dir...
#
#                       prob_dist label  \
# 396   <ProbDist with 2 samples>   neg
# 926   <ProbDist with 2 samples>   neg
# 1091  <ProbDist with 2 samples>   neg
# 1023  <ProbDist with 2 samples>   neg
# 1121  <ProbDist with 2 samples>   neg
#
#                                                features pred  pos_dist  \
# 396   {'VERB': 1, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...  pos  0.973595
# 926   {'VERB': 3, 'FOLLOWING_POS_ADV': 1, 'FOLLOWING...  pos  0.928333
# 1091  {'VERB': 1, 'FOLLOWING_POS_PUNCT': 1, 'FOLLOWI...  pos  0.907394
# 1023  {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.881702
# 1121  {'VERB': 1, 'FOLLOWING_POS_NUM': 1, 'FOLLOWING...  pos  0.880221
#
#       neg_dist
# 396   0.026405
# 926   0.071667
# 1091  0.092606
# 1023  0.118298
# 1121  0.119779

# %% [markdown]
# Final `get_sample_predictions` goal: get most uncertain
#
# `most_uncertain = np.argsort(np.abs(probs -0.5))[:4]`

# %% [markdown]
# Basically, we're going to sort by probabilities closest to 0.5 (on either side)
#
# #### most_uncertain(preds_df, label, n=5)

# %%
def most_uncertain(preds_df, label, n=5):
    dist_column = label + '_dist'
    return preds_df.iloc[np.argsort(np.abs(preds_df[dist_column]-0.5))][:n]

# %%
most_uncertain(preds_df, 'pos', 10)
# Out:
#                                          candidate_task  \
# 648   Even through the gift paper I could hear them ...
# 727   very interested in this guy and would be ready...
# 1108  to certain employees, and not proceed with the...
# 1097  up as to whether there was fair consideration ...
# 559   Freeman indicated that the Power Authority has...
# 786   For your convenience, this workshop will be he...
# 998   You cannot simultaneously prevent and prepare ...
# 903   of Trade, which began trading the options in 1...
# 380           maine impossible to get to...next option?
# 632   Their smiles catch onto my skin, little smilin...
#
#                       prob_dist label  \
# 648   <ProbDist with 2 samples>   neg
# 727   <ProbDist with 2 samples>   neg
# 1108  <ProbDist with 2 samples>   neg
# 1097  <ProbDist with 2 samples>   neg
# 559   <ProbDist with 2 samples>   neg
# 786   <ProbDist with 2 samples>   neg
# 998   <ProbDist with 2 samples>   neg
# 903   <ProbDist with 2 samples>   neg
# 380   <ProbDist with 2 samples>   pos
# 632   <ProbDist with 2 samples>   neg
#
#                                                features pred  pos_dist  \
# 648   {'VERB': 2, 'FOLLOWING_POS_PRON': 1, 'FOLLOWIN...  neg  0.499242
# 727   {'VERB': 2, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.500941
# 1108  {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.502288
# 1097  {'VERB': 2, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.502583
# 559   {'VERB': 5, 'FOLLOWING_POS_ADP': 2, 'FOLLOWING...  pos  0.502932
# 786   {'VERB': 2, 'FOLLOWING_POS_VERB': 1, 'FOLLOWIN...  neg  0.496220
# 998   {'VERB': 2, 'FOLLOWING_POS_CCONJ': 1, 'FOLLOWI...  neg  0.495866
# 903   {'VERB': 2, 'FOLLOWING_POS_VERB': 1, 'FOLLOWIN...  neg  0.493854
# 380   {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.510187
# 632   {'VERB': 2, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.510244
#
#       neg_dist
# 648   0.500758
# 727   0.499059
# 1108  0.497712
# 1097  0.497417
# 559   0.497068
# 786   0.503780
# 998   0.504134
# 903   0.506146
# 380   0.489813
# 632   0.489756

# %%
most_uncertain(preds_df, 'neg', 10)
# Out:
#                                          candidate_task  \
# 648   Even through the gift paper I could hear them ...
# 727   very interested in this guy and would be ready...
# 1108  to certain employees, and not proceed with the...
# 1097  up as to whether there was fair consideration ...
# 559   Freeman indicated that the Power Authority has...
# 786   For your convenience, this workshop will be he...
# 998   You cannot simultaneously prevent and prepare ...
# 903   of Trade, which began trading the options in 1...
# 380           maine impossible to get to...next option?
# 632   Their smiles catch onto my skin, little smilin...
#
#                       prob_dist label  \
# 648   <ProbDist with 2 samples>   neg
# 727   <ProbDist with 2 samples>   neg
# 1108  <ProbDist with 2 samples>   neg
# 1097  <ProbDist with 2 samples>   neg
# 559   <ProbDist with 2 samples>   neg
# 786   <ProbDist with 2 samples>   neg
# 998   <ProbDist with 2 samples>   neg
# 903   <ProbDist with 2 samples>   neg
# 380   <ProbDist with 2 samples>   pos
# 632   <ProbDist with 2 samples>   neg
#
#                                                features pred  pos_dist  \
# 648   {'VERB': 2, 'FOLLOWING_POS_PRON': 1, 'FOLLOWIN...  neg  0.499242
# 727   {'VERB': 2, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.500941
# 1108  {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.502288
# 1097  {'VERB': 2, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...  pos  0.502583
# 559   {'VERB': 5, 'FOLLOWING_POS_ADP': 2, 'FOLLOWING...  pos  0.502932
# 786   {'VERB': 2, 'FOLLOWING_POS_VERB': 1, 'FOLLOWIN...  neg  0.496220
# 998   {'VERB': 2, 'FOLLOWING_POS_CCONJ': 1, 'FOLLOWI...  neg  0.495866
# 903   {'VERB': 2, 'FOLLOWING_POS_VERB': 1, 'FOLLOWIN...  neg  0.493854
# 380   {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.510187
# 632   {'VERB': 2, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...  pos  0.510244
#
#       neg_dist
# 648   0.500758
# 727   0.499059
# 1108  0.497712
# 1097  0.497417
# 559   0.497068
# 786   0.503780
# 998   0.504134
# 903   0.506146
# 380   0.489813
# 632   0.489756

# %% [markdown]
# Turns out, both `label`s return the same list

# %% [markdown]
# ## Writing: aggregate_features
#
# how to correlate features to (in)correctness

# %% [markdown]
# Example set of feature dictionaries...

# %%
most_incorrect[['features']]
# Out:
#                                                features
# 396   {'VERB': 1, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...
# 926   {'VERB': 3, 'FOLLOWING_POS_ADV': 1, 'FOLLOWING...
# 1091  {'VERB': 1, 'FOLLOWING_POS_PUNCT': 1, 'FOLLOWI...
# 1023  {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...
# 1121  {'VERB': 1, 'FOLLOWING_POS_NUM': 1, 'FOLLOWING...
# 777   {'VERB': 1, 'PARENT_DEP_ROOT': 1, 'PARENT_POS_...
# 167   {'VERB': 1, 'FOLLOWING_POS_PROPN': 1, 'FOLLOWI...
# 1282  {'VERB': 1, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...
# 803   {'VERB': 1, 'FOLLOWING_POS_NOUN': 1, 'FOLLOWIN...
# 196   {'VERB': 1, 'FOLLOWING_POS_PUNCT': 1, 'FOLLOWI...
# 1111  {'VERB': 2, 'FOLLOWING_POS_CCONJ': 1, 'FOLLOWI...
# 1103  {'VERB': 3, 'FOLLOWING_POS_PUNCT': 1, 'FOLLOWI...
# 805   {'VERB': 3, 'FOLLOWING_POS_NOUN': 3, 'FOLLOWIN...
# 1118  {'VERB': 2, 'FOLLOWING_POS_DET': 1, 'FOLLOWING...
# 1011  {'VERB': 2, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...
# 964   {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...
# 828   {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...
# 256   {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...
# 1063  {'VERB': 1, 'FOLLOWING_POS_ADP': 1, 'FOLLOWING...
# 752   {'VERB': 1, 'FOLLOWING_POS_ADJ': 1, 'FOLLOWING...

# %% [markdown]
# Convert one feature dictionary to dataframe...

# %%
most_incorrect[['features']].iloc[1].values[0]
# Out:
# {'CHILD_DEP_ADVMOD': 1,
#  'CHILD_DEP_AUX': 1,
#  'CHILD_DEP_CC': 1,
#  'CHILD_DEP_CONJ': 1,
#  'CHILD_DEP_DOBJ': 1,
#  'CHILD_DEP_NPADVMOD': 1,
#  'CHILD_DEP_PUNCT': 1,
#  'CHILD_DEP_XCOMP': 1,
#  'CHILD_POSTAG_,': 1,
#  'CHILD_POSTAG_CC': 1,
#  'CHILD_POSTAG_NN': 1,
#  'CHILD_POSTAG_NNP': 1,
#  'CHILD_POSTAG_RB': 1,
#  'CHILD_POSTAG_TO': 1,
#  'CHILD_POSTAG_VB': 2,
#  'CHILD_POS_ADV': 1,
#  'CHILD_POS_CCONJ': 1,
#  'CHILD_POS_NOUN': 1,
#  'CHILD_POS_PART': 1,
#  'CHILD_POS_PROPN': 1,
#  'CHILD_POS_PUNCT': 1,
#  'CHILD_POS_VERB': 2,
#  'FOLLOWING_POSTAG_CC': 1,
#  'FOLLOWING_POSTAG_JJ': 1,
#  'FOLLOWING_POSTAG_RB': 1,
#  'FOLLOWING_POS_ADJ': 1,
#  'FOLLOWING_POS_ADV': 1,
#  'FOLLOWING_POS_CCONJ': 1,
#  'PARENT_DEP_ROOT': 2,
#  'PARENT_DEP_XCOMP': 1,
#  'PARENT_POSTAG_VB': 1,
#  'PARENT_POSTAG_VBD': 2,
#  'PARENT_POS_VERB': 3,
#  'VERB': 3}

# %%
f_dict = pd.DataFrame.from_dict(most_incorrect[['features']].iloc[1].values[0], orient='index').reset_index()
f_dict
# Out:
#                   index  0
# 0                  VERB  3
# 1     FOLLOWING_POS_ADV  1
# 2   FOLLOWING_POSTAG_RB  1
# 3       PARENT_DEP_ROOT  2
# 4       PARENT_POS_VERB  3
# 5     PARENT_POSTAG_VBD  2
# 6       CHILD_DEP_XCOMP  1
# 7        CHILD_POS_VERB  2
# 8       CHILD_POSTAG_VB  2
# 9       CHILD_DEP_PUNCT  1
# 10      CHILD_POS_PUNCT  1
# 11       CHILD_POSTAG_,  1
# 12   CHILD_DEP_NPADVMOD  1
# 13      CHILD_POS_PROPN  1
# 14     CHILD_POSTAG_NNP  1
# 15  FOLLOWING_POS_CCONJ  1
# 16  FOLLOWING_POSTAG_CC  1
# 17     CHILD_DEP_ADVMOD  1
# 18        CHILD_POS_ADV  1
# 19      CHILD_POSTAG_RB  1
# 20        CHILD_DEP_AUX  1
# 21       CHILD_POS_PART  1
# 22      CHILD_POSTAG_TO  1
# 23         CHILD_DEP_CC  1
# 24      CHILD_POS_CCONJ  1
# 25      CHILD_POSTAG_CC  1
# 26       CHILD_DEP_CONJ  1
# 27    FOLLOWING_POS_ADJ  1
# 28  FOLLOWING_POSTAG_JJ  1
# 29     PARENT_DEP_XCOMP  1
# 30     PARENT_POSTAG_VB  1
# 31       CHILD_DEP_DOBJ  1
# 32       CHILD_POS_NOUN  1
# 33      CHILD_POSTAG_NN  1

# %%
f_dict.columns = ['feature', 'count']
f_dict
# Out:
#                 feature  count
# 0                  VERB      3
# 1     FOLLOWING_POS_ADV      1
# 2   FOLLOWING_POSTAG_RB      1
# 3       PARENT_DEP_ROOT      2
# 4       PARENT_POS_VERB      3
# 5     PARENT_POSTAG_VBD      2
# 6       CHILD_DEP_XCOMP      1
# 7        CHILD_POS_VERB      2
# 8       CHILD_POSTAG_VB      2
# 9       CHILD_DEP_PUNCT      1
# 10      CHILD_POS_PUNCT      1
# 11       CHILD_POSTAG_,      1
# 12   CHILD_DEP_NPADVMOD      1
# 13      CHILD_POS_PROPN      1
# 14     CHILD_POSTAG_NNP      1
# 15  FOLLOWING_POS_CCONJ      1
# 16  FOLLOWING_POSTAG_CC      1
# 17     CHILD_DEP_ADVMOD      1
# 18        CHILD_POS_ADV      1
# 19      CHILD_POSTAG_RB      1
# 20        CHILD_DEP_AUX      1
# 21       CHILD_POS_PART      1
# 22      CHILD_POSTAG_TO      1
# 23         CHILD_DEP_CC      1
# 24      CHILD_POS_CCONJ      1
# 25      CHILD_POSTAG_CC      1
# 26       CHILD_DEP_CONJ      1
# 27    FOLLOWING_POS_ADJ      1
# 28  FOLLOWING_POSTAG_JJ      1
# 29     PARENT_DEP_XCOMP      1
# 30     PARENT_POSTAG_VB      1
# 31       CHILD_DEP_DOBJ      1
# 32       CHILD_POS_NOUN      1
# 33      CHILD_POSTAG_NN      1

# %% [markdown]
# Aggregating two feature dataframes into one by feature occurrence count...

# %%
pd.concat([f_dict, f_dict]).groupby('feature').sum().reset_index()
# Out:
#                 feature  count
# 0      CHILD_DEP_ADVMOD      2
# 1         CHILD_DEP_AUX      2
# 2          CHILD_DEP_CC      2
# 3        CHILD_DEP_CONJ      2
# 4        CHILD_DEP_DOBJ      2
# 5    CHILD_DEP_NPADVMOD      2
# 6       CHILD_DEP_PUNCT      2
# 7       CHILD_DEP_XCOMP      2
# 8        CHILD_POSTAG_,      2
# 9       CHILD_POSTAG_CC      2
# 10      CHILD_POSTAG_NN      2
# 11     CHILD_POSTAG_NNP      2
# 12      CHILD_POSTAG_RB      2
# 13      CHILD_POSTAG_TO      2
# 14      CHILD_POSTAG_VB      4
# 15        CHILD_POS_ADV      2
# 16      CHILD_POS_CCONJ      2
# 17       CHILD_POS_NOUN      2
# 18       CHILD_POS_PART      2
# 19      CHILD_POS_PROPN      2
# 20      CHILD_POS_PUNCT      2
# 21       CHILD_POS_VERB      4
# 22  FOLLOWING_POSTAG_CC      2
# 23  FOLLOWING_POSTAG_JJ      2
# 24  FOLLOWING_POSTAG_RB      2
# 25    FOLLOWING_POS_ADJ      2
# 26    FOLLOWING_POS_ADV      2
# 27  FOLLOWING_POS_CCONJ      2
# 28      PARENT_DEP_ROOT      4
# 29     PARENT_DEP_XCOMP      2
# 30     PARENT_POSTAG_VB      2
# 31    PARENT_POSTAG_VBD      4
# 32      PARENT_POS_VERB      6
# 33                 VERB      6

# %% [markdown]
# Putting it all together...

# %%
f_dicts = []
for i in range(len(most_incorrect)):
    f_dict = pd.DataFrame.from_dict(most_incorrect[['features']].iloc[i].values[0], orient='index').reset_index()
    f_dict.columns = ['feature', 'count']
    f_dicts.append(f_dict)
f_dicts
# Out:
# [               feature  count
#  0                 VERB      1
#  1   FOLLOWING_POS_NOUN      1
#  2  FOLLOWING_POSTAG_NN      1
#  3      PARENT_DEP_ROOT      1
#  4     PARENT_POS_PROPN      1
#  5    PARENT_POSTAG_NNP      1
#  6       CHILD_DEP_DOBJ      1
#  7       CHILD_POS_NOUN      1
#  8      CHILD_POSTAG_NN      1,                 feature  count
#  0                  VERB      3
#  1     FOLLOWING_POS_ADV      1
#  2   FOLLOWING_POSTAG_RB      1
#  3       PARENT_DEP_ROOT      2
#  4       PARENT_POS_VERB      3
#  5     PARENT_POSTAG_VBD      2
#  6       CHILD_DEP_XCOMP      1
#  7        CHILD_POS_VERB      2
#  8       CHILD_POSTAG_VB      2
#  9       CHILD_DEP_PUNCT      1
#  10      CHILD_POS_PUNCT      1
#  11       CHILD_POSTAG_,      1
#  12   CHILD_DEP_NPADVMOD      1
#  13      CHILD_POS_PROPN      1
#  14     CHILD_POSTAG_NNP      1
#  15  FOLLOWING_POS_CCONJ      1
#  16  FOLLOWING_POSTAG_CC      1
#  17     CHILD_DEP_ADVMOD      1
#  18        CHILD_POS_ADV      1
#  19      CHILD_POSTAG_RB      1
#  20        CHILD_DEP_AUX      1
#  21       CHILD_POS_PART      1
#  22      CHILD_POSTAG_TO      1
#  23         CHILD_DEP_CC      1
#  24      CHILD_POS_CCONJ      1
#  25      CHILD_POSTAG_CC      1
#  26       CHILD_DEP_CONJ      1
#  27    FOLLOWING_POS_ADJ      1
#  28  FOLLOWING_POSTAG_JJ      1
#  29     PARENT_DEP_XCOMP      1
#  30     PARENT_POSTAG_VB      1
#  31       CHILD_DEP_DOBJ      1
#  32       CHILD_POS_NOUN      1
#  33      CHILD_POSTAG_NN      1,                 feature  count
#  0                  VERB      1
#  1   FOLLOWING_POS_PUNCT      1
#  2    FOLLOWING_POSTAG_,      1
#  3       PARENT_DEP_ROOT      1
#  4       PARENT_POS_VERB      1
#  5      PARENT_POSTAG_VB      1
#  6       CHILD_DEP_PUNCT      1
#  7       CHILD_POS_PUNCT      1
#  8        CHILD_POSTAG_,      1
#  9        CHILD_DEP_PREP      1
#  10        CHILD_POS_ADP      1
#  11      CHILD_POSTAG_IN      1
#  12       CHILD_DEP_CONJ      1
#  13       CHILD_POS_NOUN      1
#  14      CHILD_POSTAG_NN      1,                 feature  count
#  0                  VERB      1
#  1     FOLLOWING_POS_ADP      1
#  2   FOLLOWING_POSTAG_IN      1
#  3       PARENT_DEP_ROOT      1
#  4       PARENT_POS_NOUN      1
#  5     PARENT_POSTAG_NNS      1
#  6       CHILD_DEP_PUNCT      2
#  7       CHILD_POS_PUNCT      2
#  8    CHILD_POSTAG_-LRB-      1
#  9        CHILD_DEP_MARK      1
#  10        CHILD_POS_ADP      2
#  11      CHILD_POSTAG_IN      2
#  12       CHILD_DEP_PREP      1
#  13   CHILD_POSTAG_-RRB-      1,                 feature  count
#  0                  VERB      1
#  1     FOLLOWING_POS_NUM      1
#  2   FOLLOWING_POSTAG_CD      1
#  3       PARENT_DEP_ROOT      1
#  4       PARENT_POS_VERB      1
#  5     PARENT_POSTAG_VBD      1
#  6    CHILD_DEP_NPADVMOD      1
#  7       CHILD_POS_PROPN      1
#  8      CHILD_POSTAG_NNP      1
#  9        CHILD_DEP_DOBJ      1
#  10       CHILD_POS_NOUN      1
#  11     CHILD_POSTAG_NNS      1
#  12       CHILD_DEP_PREP      1
#  13        CHILD_POS_ADP      1
#  14      CHILD_POSTAG_IN      1,              feature  count
#  0               VERB      1
#  1    PARENT_DEP_ROOT      1
#  2   PARENT_POS_PROPN      1
#  3  PARENT_POSTAG_NNP      1
#  4      CHILD_DEP_AUX      1
#  5     CHILD_POS_PART      1
#  6    CHILD_POSTAG_TO      1,                 feature  count
#  0                  VERB      1
#  1   FOLLOWING_POS_PROPN      1
#  2  FOLLOWING_POSTAG_NNP      1
#  3       PARENT_DEP_ROOT      1
#  4      PARENT_POS_PROPN      1
#  5     PARENT_POSTAG_NNP      1,                feature  count
#  0                 VERB      1
#  1    FOLLOWING_POS_DET      1
#  2  FOLLOWING_POSTAG_DT      1
#  3      PARENT_DEP_ROOT      1
#  4      PARENT_POS_VERB      1
#  5     PARENT_POSTAG_VB      1
#  6       CHILD_DEP_DOBJ      1
#  7        CHILD_POS_DET      1
#  8      CHILD_POSTAG_DT      1,                  feature  count
#  0                   VERB      1
#  1     FOLLOWING_POS_NOUN      1
#  2   FOLLOWING_POSTAG_NNS      1
#  3       PARENT_DEP_APPOS      1
#  4        PARENT_POS_NOUN      1
#  5       PARENT_POSTAG_NN      1
#  6         CHILD_DEP_DOBJ      1
#  7         CHILD_POS_NOUN      1
#  8       CHILD_POSTAG_NNS      1
#  9         CHILD_DEP_PREP      2
#  10         CHILD_POS_ADP      2
#  11       CHILD_POSTAG_IN      2,                 feature  count
#  0                  VERB      1
#  1   FOLLOWING_POS_PUNCT      1
#  2    FOLLOWING_POSTAG_:      1
#  3       PARENT_DEP_ROOT      1
#  4       PARENT_POS_VERB      1
#  5     PARENT_POSTAG_VBN      1
#  6       CHILD_DEP_PUNCT      1
#  7       CHILD_POS_PUNCT      1
#  8        CHILD_POSTAG_:      1
#  9    CHILD_DEP_NPADVMOD      1
#  10      CHILD_POS_PROPN      1
#  11     CHILD_POSTAG_NNP      1,                 feature  count
#  0                  VERB      2
#  1   FOLLOWING_POS_CCONJ      1
#  2   FOLLOWING_POSTAG_CC      1
#  3       PARENT_DEP_POBJ      1
#  4       PARENT_POS_NOUN      1
#  5      PARENT_POSTAG_NN      1
#  6         CHILD_DEP_AUX      1
#  7        CHILD_POS_PART      1
#  8       CHILD_POSTAG_TO      1
#  9          CHILD_DEP_CC      1
#  10      CHILD_POS_CCONJ      1
#  11      CHILD_POSTAG_CC      1
#  12       CHILD_DEP_CONJ      1
#  13       CHILD_POS_VERB      1
#  14      CHILD_POSTAG_VB      1
#  15    FOLLOWING_POS_DET      1
#  16  FOLLOWING_POSTAG_DT      1
#  17       PARENT_DEP_ACL      1
#  18      PARENT_POS_VERB      1
#  19     PARENT_POSTAG_VB      1,                 feature  count
#  0                  VERB      3
#  1   FOLLOWING_POS_PUNCT      1
#  2    FOLLOWING_POSTAG_:      1
#  3       PARENT_DEP_ROOT      2
#  4       PARENT_POS_VERB      3
#  5      PARENT_POSTAG_VB      3
#  6       CHILD_DEP_CCOMP      1
#  7        CHILD_POS_VERB      3
#  8       CHILD_POSTAG_VB      2
#  9     FOLLOWING_POS_DET      2
#  10  FOLLOWING_POSTAG_DT      2
#  11      CHILD_DEP_PUNCT      1
#  12      CHILD_POS_PUNCT      1
#  13       CHILD_POSTAG_:      1
#  14     CHILD_DEP_ADVMOD      1
#  15        CHILD_POS_ADV      1
#  16      CHILD_POSTAG_RB      1
#  17      CHILD_DEP_NSUBJ      1
#  18       CHILD_POS_NOUN      2
#  19      CHILD_POSTAG_NN      1
#  20        CHILD_DEP_AUX      1
#  21      CHILD_POSTAG_MD      1
#  22       CHILD_DEP_DOBJ      2
#  23     CHILD_POSTAG_NNS      1
#  24         CHILD_DEP_CC      1
#  25      CHILD_POS_CCONJ      1
#  26      CHILD_POSTAG_CC      1
#  27       CHILD_DEP_CONJ      1
#  28     PARENT_DEP_CCOMP      1
#  29        CHILD_POS_DET      1
#  30      CHILD_POSTAG_DT      1,                  feature  count
#  0                   VERB      3
#  1     FOLLOWING_POS_NOUN      3
#  2    FOLLOWING_POSTAG_NN      1
#  3        PARENT_DEP_ROOT      2
#  4        PARENT_POS_NOUN      2
#  5       PARENT_POSTAG_NN      2
#  6       CHILD_DEP_ADVMOD      1
#  7          CHILD_POS_ADV      1
#  8        CHILD_POSTAG_RB      1
#  9   FOLLOWING_POSTAG_NNS      2
#  10        CHILD_DEP_DOBJ      2
#  11        CHILD_POS_NOUN      2
#  12      CHILD_POSTAG_NNS      2
#  13          CHILD_DEP_CC      1
#  14       CHILD_POS_CCONJ      1
#  15       CHILD_POSTAG_CC      1
#  16        CHILD_DEP_CONJ      1
#  17        CHILD_POS_VERB      1
#  18      CHILD_POSTAG_VBG      1
#  19        PARENT_DEP_ACL      1
#  20       PARENT_POS_VERB      1
#  21     PARENT_POSTAG_VBG      1
#  22        CHILD_DEP_PREP      1
#  23         CHILD_POS_ADP      1
#  24       CHILD_POSTAG_IN      1,                 feature  count
#  0                  VERB      2
#  1     FOLLOWING_POS_DET      1
#  2   FOLLOWING_POSTAG_DT      1
#  3       PARENT_DEP_ROOT      2
#  4       PARENT_POS_VERB      2
#  5      PARENT_POSTAG_VB      2
#  6         CHILD_DEP_AUX      2
#  7        CHILD_POS_PART      2
#  8       CHILD_POSTAG_TO      2
#  9        CHILD_DEP_DOBJ      1
#  10       CHILD_POS_NOUN      1
#  11      CHILD_POSTAG_NN      1
#  12      CHILD_DEP_XCOMP      1
#  13       CHILD_POS_VERB      1
#  14      CHILD_POSTAG_VB      1
#  15    FOLLOWING_POS_ADP      1
#  16  FOLLOWING_POSTAG_IN      1
#  17       CHILD_DEP_PREP      1
#  18        CHILD_POS_ADP      1
#  19      CHILD_POSTAG_IN      1,                 feature  count
#  0                  VERB      2
#  1     FOLLOWING_POS_ADJ      1
#  2   FOLLOWING_POSTAG_JJ      1
#  3       PARENT_DEP_ROOT      2
#  4       PARENT_POS_NOUN      2
#  5      PARENT_POSTAG_NN      2
#  6        CHILD_DEP_DOBJ      2
#  7        CHILD_POS_NOUN      1
#  8      CHILD_POSTAG_NNS      1
#  9     FOLLOWING_POS_DET      1
#  10  FOLLOWING_POSTAG_DT      1
#  11        CHILD_DEP_AUX      1
#  12       CHILD_POS_PART      1
#  13      CHILD_POSTAG_TO      1
#  14        CHILD_POS_DET      1
#  15      CHILD_POSTAG_DT      1,                feature  count
#  0                 VERB      1
#  1    FOLLOWING_POS_ADP      1
#  2  FOLLOWING_POSTAG_IN      1
#  3      PARENT_DEP_ROOT      1
#  4      PARENT_POS_NOUN      1
#  5    PARENT_POSTAG_NNS      1
#  6       CHILD_DEP_PREP      1
#  7        CHILD_POS_ADP      1
#  8      CHILD_POSTAG_IN      1,                feature  count
#  0                 VERB      1
#  1    FOLLOWING_POS_ADP      1
#  2  FOLLOWING_POSTAG_IN      1
#  3      PARENT_DEP_ROOT      1
#  4      PARENT_POS_NOUN      1
#  5    PARENT_POSTAG_NNS      1
#  6       CHILD_DEP_PREP      1
#  7        CHILD_POS_ADP      1
#  8      CHILD_POSTAG_IN      1,                feature  count
#  0                 VERB      1
#  1    FOLLOWING_POS_ADP      1
#  2  FOLLOWING_POSTAG_IN      1
#  3      PARENT_DEP_ROOT      1
#  4      PARENT_POS_NOUN      1
#  5    PARENT_POSTAG_NNS      1
#  6       CHILD_DEP_PREP      1
#  7        CHILD_POS_ADP      1
#  8      CHILD_POSTAG_IN      1,                feature  count
#  0                 VERB      1
#  1    FOLLOWING_POS_ADP      1
#  2  FOLLOWING_POSTAG_IN      1
#  3      PARENT_DEP_ROOT      1
#  4      PARENT_POS_NOUN      1
#  5    PARENT_POSTAG_NNS      1
#  6       CHILD_DEP_PREP      1
#  7        CHILD_POS_ADP      1
#  8      CHILD_POSTAG_IN      1,                   feature  count
#  0                    VERB      1
#  1       FOLLOWING_POS_ADJ      1
#  2   FOLLOWING_POSTAG_PRP$      1
#  3         PARENT_DEP_ROOT      1
#  4         PARENT_POS_VERB      1
#  5        PARENT_POSTAG_VB      1
#  6          CHILD_DEP_INTJ      1
#  7          CHILD_POS_INTJ      1
#  8         CHILD_POSTAG_UH      1
#  9          CHILD_DEP_DOBJ      1
#  10         CHILD_POS_NOUN      1
#  11        CHILD_POSTAG_NN      1
#  12     CHILD_DEP_NPADVMOD      1
#  13          CHILD_POS_NUM      1
#  14        CHILD_POSTAG_CD      1]

# %%
pd.concat(f_dicts).groupby('feature').sum().sort_values('count', ascending=False).reset_index()
# Out:
#                   feature  count
# 0                    VERB     29
# 1         PARENT_DEP_ROOT     23
# 2         PARENT_POS_VERB     15
# 3          CHILD_DEP_DOBJ     13
# 4         CHILD_POSTAG_IN     12
# 5           CHILD_POS_ADP     12
# 6          CHILD_POS_NOUN     12
# 7         PARENT_POS_NOUN     11
# 8          CHILD_DEP_PREP     11
# 9        PARENT_POSTAG_VB     10
# 10         CHILD_POS_VERB      8
# 11          CHILD_DEP_AUX      7
# 12         CHILD_POS_PART      6
# 13        CHILD_POSTAG_TO      6
# 14        CHILD_POSTAG_VB      6
# 15    FOLLOWING_POSTAG_IN      6
# 16    FOLLOWING_POSTAG_DT      6
# 17        CHILD_POSTAG_NN      6
# 18      FOLLOWING_POS_ADP      6
# 19      FOLLOWING_POS_DET      6
# 20       PARENT_POSTAG_NN      6
# 21       CHILD_POSTAG_NNS      6
# 22        CHILD_POS_PUNCT      6
# 23        CHILD_DEP_PUNCT      6
# 24         CHILD_DEP_CONJ      5
# 25      PARENT_POSTAG_NNS      5
# 26     FOLLOWING_POS_NOUN      5
# 27           CHILD_DEP_CC      4
# 28        CHILD_POSTAG_CC      4
# 29        CHILD_POS_CCONJ      4
# ..                    ...    ...
# 49    FOLLOWING_POS_CCONJ      2
# 50        CHILD_DEP_XCOMP      2
# 51    FOLLOWING_POSTAG_CC      2
# 52     FOLLOWING_POSTAG_:      2
# 53       PARENT_DEP_XCOMP      1
# 54         CHILD_DEP_INTJ      1
# 55     CHILD_POSTAG_-LRB-      1
# 56      PARENT_POSTAG_VBG      1
# 57       CHILD_POSTAG_VBG      1
# 58        CHILD_POSTAG_CD      1
# 59        CHILD_POSTAG_UH      1
# 60        PARENT_DEP_POBJ      1
# 61      PARENT_POSTAG_VBN      1
# 62        CHILD_DEP_CCOMP      1
# 63         CHILD_DEP_MARK      1
# 64      FOLLOWING_POS_NUM      1
# 65       PARENT_DEP_CCOMP      1
# 66       PARENT_DEP_APPOS      1
# 67    FOLLOWING_POS_PROPN      1
# 68         CHILD_POS_INTJ      1
# 69      FOLLOWING_POS_ADV      1
# 70        CHILD_DEP_NSUBJ      1
# 71          CHILD_POS_NUM      1
# 72    FOLLOWING_POSTAG_RB      1
# 73        CHILD_POSTAG_MD      1
# 74     CHILD_POSTAG_-RRB-      1
# 75   FOLLOWING_POSTAG_NNP      1
# 76    FOLLOWING_POSTAG_CD      1
# 77     FOLLOWING_POSTAG_,      1
# 78  FOLLOWING_POSTAG_PRP$      1
#
# [79 rows x 2 columns]

# %% [markdown]
# #### aggregate_features(preds_df, n=0)

# %%
def aggregate_features(preds_df, n=0):
    f_dicts = []
    for i in range(len(most_incorrect)):
        f_dict = pd.DataFrame.from_dict(preds_df[['features']].iloc[i].values[0], orient='index').reset_index()
        f_dict.columns = ['feature', 'count']
        f_dicts.append(f_dict)
    
    agg = pd.concat(f_dicts).groupby('feature').sum().sort_values('count', ascending=False).reset_index()
    
    if n <= 0:
        return agg
    else:
        return agg[:n]

# %%
aggregate_features(most_incorrect)
# Out:
#                   feature  count
# 0                    VERB     29
# 1         PARENT_DEP_ROOT     23
# 2         PARENT_POS_VERB     15
# 3          CHILD_DEP_DOBJ     13
# 4         CHILD_POSTAG_IN     12
# 5           CHILD_POS_ADP     12
# 6          CHILD_POS_NOUN     12
# 7         PARENT_POS_NOUN     11
# 8          CHILD_DEP_PREP     11
# 9        PARENT_POSTAG_VB     10
# 10         CHILD_POS_VERB      8
# 11          CHILD_DEP_AUX      7
# 12         CHILD_POS_PART      6
# 13        CHILD_POSTAG_TO      6
# 14        CHILD_POSTAG_VB      6
# 15    FOLLOWING_POSTAG_IN      6
# 16    FOLLOWING_POSTAG_DT      6
# 17        CHILD_POSTAG_NN      6
# 18      FOLLOWING_POS_ADP      6
# 19      FOLLOWING_POS_DET      6
# 20       PARENT_POSTAG_NN      6
# 21       CHILD_POSTAG_NNS      6
# 22        CHILD_POS_PUNCT      6
# 23        CHILD_DEP_PUNCT      6
# 24         CHILD_DEP_CONJ      5
# 25      PARENT_POSTAG_NNS      5
# 26     FOLLOWING_POS_NOUN      5
# 27           CHILD_DEP_CC      4
# 28        CHILD_POSTAG_CC      4
# 29        CHILD_POS_CCONJ      4
# ..                    ...    ...
# 49    FOLLOWING_POS_CCONJ      2
# 50        CHILD_DEP_XCOMP      2
# 51    FOLLOWING_POSTAG_CC      2
# 52     FOLLOWING_POSTAG_:      2
# 53       PARENT_DEP_XCOMP      1
# 54         CHILD_DEP_INTJ      1
# 55     CHILD_POSTAG_-LRB-      1
# 56      PARENT_POSTAG_VBG      1
# 57       CHILD_POSTAG_VBG      1
# 58        CHILD_POSTAG_CD      1
# 59        CHILD_POSTAG_UH      1
# 60        PARENT_DEP_POBJ      1
# 61      PARENT_POSTAG_VBN      1
# 62        CHILD_DEP_CCOMP      1
# 63         CHILD_DEP_MARK      1
# 64      FOLLOWING_POS_NUM      1
# 65       PARENT_DEP_CCOMP      1
# 66       PARENT_DEP_APPOS      1
# 67    FOLLOWING_POS_PROPN      1
# 68         CHILD_POS_INTJ      1
# 69      FOLLOWING_POS_ADV      1
# 70        CHILD_DEP_NSUBJ      1
# 71          CHILD_POS_NUM      1
# 72    FOLLOWING_POSTAG_RB      1
# 73        CHILD_POSTAG_MD      1
# 74     CHILD_POSTAG_-RRB-      1
# 75   FOLLOWING_POSTAG_NNP      1
# 76    FOLLOWING_POSTAG_CD      1
# 77     FOLLOWING_POSTAG_,      1
# 78  FOLLOWING_POSTAG_PRP$      1
#
# [79 rows x 2 columns]

# %%
aggregate_features(most_incorrect, 10)
# Out:
#             feature  count
# 0              VERB     29
# 1   PARENT_DEP_ROOT     23
# 2   PARENT_POS_VERB     15
# 3    CHILD_DEP_DOBJ     13
# 4   CHILD_POSTAG_IN     12
# 5     CHILD_POS_ADP     12
# 6    CHILD_POS_NOUN     12
# 7   PARENT_POS_NOUN     11
# 8    CHILD_DEP_PREP     11
# 9  PARENT_POSTAG_VB     10

# %%
aggregate_features(most_correct, 10)
# Out:
#              feature  count
# 0               VERB     49
# 1    PARENT_POS_VERB     37
# 2    CHILD_DEP_NSUBJ     35
# 3     CHILD_POS_NOUN     35
# 4    PARENT_DEP_ROOT     34
# 5    CHILD_POSTAG_NN     28
# 6  PARENT_POSTAG_VBZ     28
# 7    CHILD_POS_PUNCT     24
# 8    CHILD_DEP_PUNCT     24
# 9      CHILD_POS_ADJ     16
